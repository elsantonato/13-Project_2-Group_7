# %%
import pandas as pd
import matplotlib as plt
import json
import requests
from pprint import pprint

# %% [markdown]
# <h2>Scraping Base Data (Top 100 Grossing Movies)

# %%
# Scrape the base data from the-numbers.com (for Top 100 Grossing Movies)
response = requests.get("https://www.the-numbers.com/box-office-records/domestic/all-movies/cumulative/all-time")
base_df_1 = pd.read_html(response.text)[0]
base_df_2 = pd.read_html(response.text)[1]
base_df = base_df_1.append(base_df_2).reset_index(drop=True)

# Fix cut off titles
base_df = base_df.replace(base_df.iloc[74]['Movie'], 'Pirates of the Caribbean: The Curse of the Black Pearl')
base_df = base_df.replace(base_df.iloc[87]['Movie'], 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe')

base_df = base_df.rename(columns = {"Movie":"title", "Released": "year"})

base_df.head()
# Out:
#    Rank  year                                 title DomesticBox Office  \
# 0     1  2015  Star Wars Ep. VII: The Force Awakens       $936,662,225
# 1     2  2009                                Avatar       $760,507,625
# 2     3  2018                         Black Panther       $700,059,566
# 3     4  2018                Avengers: Infinity War       $678,815,482
# 4     5  1997                               Titanic       $659,363,944
#
#   InternationalBox Office WorldwideBox Office
# 0          $1,116,648,995      $2,053,311,220
# 1          $2,015,837,654      $2,776,345,279
# 2            $648,300,000      $1,348,359,566
# 3          $1,369,988,242      $2,048,803,724
# 4          $1,548,844,451      $2,208,208,395

# %%
#Extra API key: cd87cd45
url = 'http://www.omdbapi.com/?apikey=8cc26962&r=json'
# Out:
# 'http://www.omdbapi.com/?apikey=8cc26962&r=json'

# %% [markdown]
# <h2>Scraping IMDB Data from OMDB API

# %%
imdb_dicts=[]

for index, row in base_df.iterrows():

    title = row['title']
    year = row['year']
    
    title = title.replace('â', '\'')
    
    # Change title formatting to IMDB formatting for special cases
    if 'Star Wars' in title:
        title = title.replace('Ep.', 'Episode').replace(':', ' -')
        if 'Episode VII ' in title:
            title = 'Star Wars: Episode VII'
    if 'Harry Potter' in title:
        if 'II' in title:
            title = title.replace('II', '2')
        elif 'I' in title:
            title = title.replace('I', '1')
        
    try: 
        # Prepare URL
        query_url = f"{url}&t={title}&y={year}"
        
        # Make the call to the API
        omdb_dict = requests.get(query_url).json()
        
        # Append data to the list of dictionaries
        imdb_dicts.append({"title": row['title'],
                          "year": omdb_dict['Year'],
                          "genre": omdb_dict['Genre'],
                          "director": omdb_dict['Director'],
                          "main_cast": omdb_dict['Actors'],
                          "writer": omdb_dict['Writer'],
                          "language": omdb_dict['Language'],
                          "country": omdb_dict['Country'],
                          "awards": omdb_dict['Awards'],
                          "imdbRating": omdb_dict['imdbRating'],
                          "imdbVotes": omdb_dict['imdbVotes'],
                          "box_office": omdb_dict['BoxOffice'],
                          "studio": omdb_dict['Production']})
    except:
        print(title, year)
    
imdb_df = pd.DataFrame(imdb_dicts)
imdb_df = imdb_df[["title", "year", "genre", "director", "main_cast", "writer", \
                    "language", "country", "awards", "imdbRating", "imdbVotes", \
                    "box_office", "studio"]]
imdb_df.head()
# Out:
#                                   title  year  \
# 0  Star Wars Ep. VII: The Force Awakens  2015
# 1                                Avatar  2009
# 2                         Black Panther  2018
# 3                Avengers: Infinity War  2018
# 4                               Titanic  1997
#
#                                 genre                  director  \
# 0                               Short                       N/A
# 1  Action, Adventure, Fantasy, Sci-Fi             James Cameron
# 2           Action, Adventure, Sci-Fi              Ryan Coogler
# 3  Action, Adventure, Fantasy, Sci-Fi  Anthony Russo, Joe Russo
# 4                      Drama, Romance             James Cameron
#
#                                            main_cast  \
# 0                                     Freddie Kuguru
# 1  Sam Worthington, Zoe Saldana, Sigourney Weaver...
# 2  Chadwick Boseman, Michael B. Jordan, Lupita Ny...
# 3  Robert Downey Jr., Chris Hemsworth, Mark Ruffa...
# 4  Leonardo DiCaprio, Kate Winslet, Billy Zane, K...
#
#                                               writer  \
# 0                                                N/A
# 1                                      James Cameron
# 2  Ryan Coogler, Joe Robert Cole, Stan Lee (based...
# 3  Christopher Markus (screenplay by), Stephen Mc...
# 4                                      James Cameron
#
#                                 language  \
# 0                                English
# 1                       English, Spanish
# 2  Swahili, Nama, English, Xhosa, Korean
# 3                                English
# 4                       English, Swedish
#
#                                      country  \
# 0                                        USA
# 1                                    UK, USA
# 2  USA, South Africa, South Korea, Australia
# 3                                        USA
# 4                                        USA
#
#                                               awards imdbRating  imdbVotes  \
# 0                                                N/A        N/A        N/A
# 1   Won 3 Oscars. Another 85 wins & 128 nominations.        7.8  1,013,715
# 2                                    14 nominations.        7.4    430,289
# 3                                                N/A        8.5    550,743
# 4  Won 11 Oscars. Another 111 wins & 77 nominations.        7.8    926,635
#
#      box_office                studio
# 0           N/A                   N/A
# 1  $749,700,000      20th Century Fox
# 2  $501,105,037        Marvel Studios
# 3  $664,987,816  Walt Disney Pictures
# 4           N/A    Paramount Pictures

# %%
new_base_df = base_df.copy() # delete later on merge

# Merge with Base Table
imdb_df['year'] = pd.to_numeric(imdb_df['year'], errors='ignore')
new_base_df2 = pd.merge(new_base_df, imdb_df, how='right', on=['title','year'])
new_base_df2
# Out:
#     Rank  year                                              title  \
# 0      1  2015               Star Wars Ep. VII: The Force Awakens
# 1      2  2009                                             Avatar
# 2      3  2018                                      Black Panther
# 3      4  2018                             Avengers: Infinity War
# 4      5  1997                                            Titanic
# 5      6  2015                                     Jurassic World
# 6      7  2012                                       The Avengers
# 7      8  2017                  Star Wars Ep. VIII: The Last Jedi
# 8      9  2018                                      Incredibles 2
# 9     10  2008                                    The Dark Knight
# 10    11  2016                       Rogue One: A Star Wars Story
# 11    12  2017                               Beauty and the Beast
# 12    13  2016                                       Finding Dory
# 13    14  1999                Star Wars Ep. I: The Phantom Menace
# 14    15  1977                       Star Wars Ep. IV: A New Hope
# 15    16  2015                            Avengers: Age of Ultron
# 16    17  2012                              The Dark Knight Rises
# 17    18  2004                                            Shrek 2
# 18    19  1982                          ET: The Extra-Terrestrial
# 19    20  2013                    The Hunger Games: Catching Fire
# 20    21  2006       Pirates of the Caribbean: Dead Manâs Chest
# 21    22  1994                                      The Lion King
# 22    23  2018                     Jurassic World: Fallen Kingdom
# 23    24  2010                                        Toy Story 3
# 24    25  2017                                       Wonder Woman
# 25    26  2013                                         Iron Man 3
# 26    27  2016                         Captain America: Civil War
# 27    28  2012                                   The Hunger Games
# 28    29  2017                     Jumanji: Welcome to the Jungle
# 29    30  2002                                         Spider-Man
# ..   ...   ...                                                ...
# 70    71  2002             Star Wars Ep. II: Attack of the Clones
# 71    72  2007         Pirates of the Caribbean: At Worldâs End
# 72    73  1983               Star Wars Ep. VI: Return of the Jedi
# 73    74  1996                                   Independence Day
# 74    75  2003  Pirates of the Caribbean: The Curse of the Bla...
# 75    76  2012                                            Skyfall
# 76    77  2012                  The Hobbit: An Unexpected Journey
# 77    78  2009             Harry Potter and the Half-Blood Prince
# 78    79  2010                         The Twilight Saga: Eclipse
# 79    80  2009                        The Twilight Saga: New Moon
# 80    81  2010       Harry Potter and the Deathly Hallows: Part I
# 81    82  2018                                            Aquaman
# 82    83  1999                                    The Sixth Sense
# 83    84  2009                                                 Up
# 84    85  2010                                          Inception
# 85    86  2012           The Twilight Saga: Breaking Dawn, Part 2
# 86    87  2007          Harry Potter and the Order of the Phoenix
# 87    88  2005  The Chronicles of Narnia: The Lion, the Witch ...
# 88    89  2013                                       Man of Steel
# 89    90  1980           Star Wars Ep. V: The Empire Strikes Back
# 90    91  2005                Harry Potter and the Goblet of Fire
# 91    92  2001                                     Monsters, Inc.
# 92    93  1990                                         Home Alone
# 93    94  2015              The Hunger Games: Mockingjay - Part 2
# 94    95  2003                                The Matrix Reloaded
# 95    96  2011           The Twilight Saga: Breaking Dawn, Part 1
# 96    97  2004                                   Meet the Fockers
# 97    98  2009                                       The Hangover
# 98    99  2013                                            Gravity
# 99   100  2016                                               Sing
#
#    DomesticBox Office InternationalBox Office WorldwideBox Office  \
# 0        $936,662,225          $1,116,648,995      $2,053,311,220
# 1        $760,507,625          $2,015,837,654      $2,776,345,279
# 2        $700,059,566            $648,300,000      $1,348,359,566
# 3        $678,815,482          $1,369,988,242      $2,048,803,724
# 4        $659,363,944          $1,548,844,451      $2,208,208,395
# 5        $652,270,625            $996,584,239      $1,648,854,864
# 6        $623,279,547            $894,656,350      $1,517,935,897
# 7        $620,181,382            $696,583,402      $1,316,764,784
# 8        $608,581,744            $634,000,000      $1,242,581,744
# 9        $533,720,947            $468,275,260      $1,001,996,207
# 10       $532,177,324            $516,926,732      $1,049,104,056
# 11       $504,014,165            $755,185,541      $1,259,199,706
# 12       $486,295,561            $534,926,806      $1,021,222,367
# 13       $474,544,677            $552,500,000      $1,027,044,677
# 14       $460,998,007            $325,600,000        $786,598,007
# 15       $459,005,868            $944,008,095      $1,403,013,963
# 16       $448,139,099            $636,300,000      $1,084,439,099
# 17       $441,226,247            $495,781,885        $937,008,132
# 18       $435,110,554            $357,854,772        $792,965,326
# 19       $424,668,047            $440,200,000        $864,868,047
# 20       $423,315,812            $642,900,000      $1,066,215,812
# 21       $421,785,283            $564,429,585        $986,214,868
# 22       $417,719,760            $888,053,039      $1,305,772,799
# 23       $415,004,880            $653,874,642      $1,068,879,522
# 24       $412,563,408            $408,569,970        $821,133,378
# 25       $408,992,272            $806,400,000      $1,215,392,272
# 26       $408,084,349            $731,990,668      $1,140,075,017
# 27       $408,010,692            $269,912,687        $677,923,379
# 28       $404,508,916            $559,987,277        $964,496,193
# 29       $403,706,375            $418,000,000        $821,706,375
# ..                ...                     ...                 ...
# 70       $310,676,740            $346,018,875        $656,695,615
# 71       $309,420,425            $654,000,000        $963,420,425
# 72       $309,205,079            $263,500,000        $572,705,079
# 73       $306,169,255            $511,231,623        $817,400,878
# 74       $305,411,224            $329,542,879        $634,954,103
# 75       $304,360,277            $806,166,704      $1,110,526,981
# 76       $303,003,568            $714,000,000      $1,017,003,568
# 77       $302,089,278            $633,124,489        $935,213,767
# 78       $300,531,751            $405,571,077        $706,102,828
# 79       $296,623,634            $390,934,093        $687,557,727
# 80       $296,131,568            $664,300,000        $960,431,568
# 81       $294,006,848            $726,758,175      $1,020,765,023
# 82       $293,506,292            $379,300,000        $672,806,292
# 83       $293,004,164            $438,459,213        $731,463,377
# 84       $292,576,195            $539,825,887        $832,402,082
# 85       $292,324,737            $537,400,000        $829,724,737
# 86       $292,137,260            $650,939,197        $943,076,457
# 87       $291,710,957            $428,828,615        $720,539,572
# 88       $291,045,518            $376,954,000        $667,999,518
# 89       $290,271,960            $243,889,374        $534,161,334
# 90       $290,201,752            $606,898,042        $897,099,794
# 91       $289,423,425            $270,334,294        $559,757,719
# 92       $285,761,243            $190,923,432        $476,684,675
# 93       $281,723,902            $367,262,885        $648,986,787
# 94       $281,553,689            $457,023,240        $738,576,929
# 95       $281,287,133            $408,132,918        $689,420,051
# 96       $279,167,575            $237,400,000        $516,567,575
# 97       $277,322,503            $188,441,583        $465,764,086
# 98       $274,092,705            $419,605,968        $693,698,673
# 99       $270,329,045            $364,129,526        $634,458,571
#
#                                                 genre  \
# 0                                               Short
# 1                  Action, Adventure, Fantasy, Sci-Fi
# 2                           Action, Adventure, Sci-Fi
# 3                  Action, Adventure, Fantasy, Sci-Fi
# 4                                      Drama, Romance
# 5                           Action, Adventure, Sci-Fi
# 6                           Action, Adventure, Sci-Fi
# 7                  Action, Adventure, Fantasy, Sci-Fi
# 8   Animation, Action, Adventure, Comedy, Family, ...
# 9                      Action, Crime, Drama, Thriller
# 10                          Action, Adventure, Sci-Fi
# 11                  Family, Fantasy, Musical, Romance
# 12               Animation, Adventure, Comedy, Family
# 13                 Action, Adventure, Fantasy, Sci-Fi
# 14                 Action, Adventure, Fantasy, Sci-Fi
# 15                          Action, Adventure, Sci-Fi
# 16                                   Action, Thriller
# 17  Animation, Adventure, Comedy, Family, Fantasy,...
# 18                                     Family, Sci-Fi
# 19                Action, Adventure, Sci-Fi, Thriller
# 20                         Action, Adventure, Fantasy
# 21       Animation, Adventure, Drama, Family, Musical
# 22                          Action, Adventure, Sci-Fi
# 23      Animation, Adventure, Comedy, Family, Fantasy
# 24            Action, Adventure, Fantasy, Sci-Fi, War
# 25                          Action, Adventure, Sci-Fi
# 26                          Action, Adventure, Sci-Fi
# 27                Action, Adventure, Sci-Fi, Thriller
# 28                 Action, Adventure, Comedy, Fantasy
# 29                          Action, Adventure, Sci-Fi
# ..                                                ...
# 70                 Action, Adventure, Fantasy, Sci-Fi
# 71                         Action, Adventure, Fantasy
# 72                 Action, Adventure, Fantasy, Sci-Fi
# 73                          Action, Adventure, Sci-Fi
# 74                         Action, Adventure, Fantasy
# 75                        Action, Adventure, Thriller
# 76                         Adventure, Family, Fantasy
# 77                Adventure, Family, Fantasy, Mystery
# 78                 Adventure, Drama, Fantasy, Romance
# 79                 Adventure, Drama, Fantasy, Romance
# 80                        Adventure, Fantasy, Mystery
# 81                 Action, Adventure, Fantasy, Sci-Fi
# 82                           Drama, Mystery, Thriller
# 83               Animation, Adventure, Comedy, Family
# 84                Action, Adventure, Sci-Fi, Thriller
# 85                 Adventure, Drama, Fantasy, Romance
# 86                Adventure, Family, Fantasy, Mystery
# 87                         Adventure, Family, Fantasy
# 88                 Action, Adventure, Fantasy, Sci-Fi
# 89                 Action, Adventure, Fantasy, Sci-Fi
# 90                Adventure, Family, Fantasy, Mystery
# 91      Animation, Adventure, Comedy, Family, Fantasy
# 92                                     Comedy, Family
# 93                Action, Adventure, Sci-Fi, Thriller
# 94                                     Action, Sci-Fi
# 95                 Adventure, Drama, Fantasy, Romance
# 96                                    Comedy, Romance
# 97                                             Comedy
# 98                            Drama, Sci-Fi, Thriller
# 99                 Animation, Comedy, Family, Musical
#
#                                              director  \
# 0                                                 N/A
# 1                                       James Cameron
# 2                                        Ryan Coogler
# 3                            Anthony Russo, Joe Russo
# 4                                       James Cameron
# 5                                     Colin Trevorrow
# 6                                         Joss Whedon
# 7                                        Rian Johnson
# 8                                           Brad Bird
# 9                                   Christopher Nolan
# 10                                     Gareth Edwards
# 11                                        Bill Condon
# 12         Andrew Stanton, Angus MacLane(co-director)
# 13                                       George Lucas
# 14                                       George Lucas
# 15                                        Joss Whedon
# 16                                  Christopher Nolan
# 17        Andrew Adamson, Kelly Asbury, Conrad Vernon
# 18                                   Steven Spielberg
# 19                                   Francis Lawrence
# 20                                     Gore Verbinski
# 21                          Roger Allers, Rob Minkoff
# 22                                        J.A. Bayona
# 23                                        Lee Unkrich
# 24                                      Patty Jenkins
# 25                                        Shane Black
# 26                           Anthony Russo, Joe Russo
# 27                                          Gary Ross
# 28                                        Jake Kasdan
# 29                                          Sam Raimi
# ..                                                ...
# 70                                       George Lucas
# 71                                     Gore Verbinski
# 72                                   Richard Marquand
# 73                                    Roland Emmerich
# 74                                     Gore Verbinski
# 75                                         Sam Mendes
# 76                                      Peter Jackson
# 77                                        David Yates
# 78                                        David Slade
# 79                                        Chris Weitz
# 80                                        David Yates
# 81                                          James Wan
# 82                                 M. Night Shyamalan
# 83             Pete Docter, Bob Peterson(co-director)
# 84                                  Christopher Nolan
# 85                                        Bill Condon
# 86                                        David Yates
# 87                                     Andrew Adamson
# 88                                        Zack Snyder
# 89                                     Irvin Kershner
# 90                                        Mike Newell
# 91  Pete Docter, David Silverman(co-director), Lee...
# 92                                     Chris Columbus
# 93                                   Francis Lawrence
# 94                    Lana Wachowski, Lilly Wachowski
# 95                                        Bill Condon
# 96                                          Jay Roach
# 97                                      Todd Phillips
# 98                                     Alfonso Cuarón
# 99  Garth Jennings, Christophe Lourdelet(co-director)
#
#                                             main_cast  \
# 0                                      Freddie Kuguru
# 1   Sam Worthington, Zoe Saldana, Sigourney Weaver...
# 2   Chadwick Boseman, Michael B. Jordan, Lupita Ny...
# 3   Robert Downey Jr., Chris Hemsworth, Mark Ruffa...
# 4   Leonardo DiCaprio, Kate Winslet, Billy Zane, K...
# 5   Chris Pratt, Bryce Dallas Howard, Irrfan Khan,...
# 6   Robert Downey Jr., Chris Evans, Mark Ruffalo, ...
# 7   Mark Hamill, Carrie Fisher, Adam Driver, Daisy...
# 8   Craig T. Nelson, Holly Hunter, Sarah Vowell, H...
# 9   Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 10  Felicity Jones, Diego Luna, Alan Tudyk, Donnie...
# 11     Emma Watson, Dan Stevens, Luke Evans, Josh Gad
# 12  Ellen DeGeneres, Albert Brooks, Ed O'Neill, Ka...
# 13  Liam Neeson, Ewan McGregor, Natalie Portman, J...
# 14  Mark Hamill, Harrison Ford, Carrie Fisher, Pet...
# 15  Robert Downey Jr., Chris Hemsworth, Mark Ruffa...
# 16  Christian Bale, Gary Oldman, Tom Hardy, Joseph...
# 17  Mike Myers, Eddie Murphy, Cameron Diaz, Julie ...
# 18  Dee Wallace, Henry Thomas, Peter Coyote, Rober...
# 19  Jennifer Lawrence, Liam Hemsworth, Jack Quaid,...
# 20  Johnny Depp, Orlando Bloom, Keira Knightley, J...
# 21  Rowan Atkinson, Matthew Broderick, Niketa Cala...
# 22  Chris Pratt, Bryce Dallas Howard, Rafe Spall, ...
# 23      Tom Hanks, Tim Allen, Joan Cusack, Ned Beatty
# 24  Gal Gadot, Chris Pine, Connie Nielsen, Robin W...
# 25  Robert Downey Jr., Gwyneth Paltrow, Don Cheadl...
# 26  Chris Evans, Robert Downey Jr., Scarlett Johan...
# 27  Stanley Tucci, Wes Bentley, Jennifer Lawrence,...
# 28  Dwayne Johnson, Kevin Hart, Jack Black, Karen ...
# 29  Tobey Maguire, Willem Dafoe, Kirsten Dunst, Ja...
# ..                                                ...
# 70  Ewan McGregor, Natalie Portman, Hayden Christe...
# 71  Johnny Depp, Geoffrey Rush, Orlando Bloom, Kei...
# 72  Mark Hamill, Harrison Ford, Carrie Fisher, Bil...
# 73  Will Smith, Bill Pullman, Jeff Goldblum, Mary ...
# 74  Johnny Depp, Geoffrey Rush, Orlando Bloom, Kei...
# 75  Daniel Craig, Judi Dench, Javier Bardem, Ralph...
# 76  Ian McKellen, Martin Freeman, Richard Armitage...
# 77  Daniel Radcliffe, Michael Gambon, Dave Legeno,...
# 78  Xavier Samuel, Kristen Stewart, Robert Pattins...
# 79  Kristen Stewart, Christina Jastrzembska, Rober...
# 80  Bill Nighy, Emma Watson, Richard Griffiths, Ha...
# 81  Jason Momoa, Amber Heard, Willem Dafoe, Patric...
# 82  Bruce Willis, Haley Joel Osment, Toni Collette...
# 83  Edward Asner, Christopher Plummer, Jordan Naga...
# 84  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...
# 85  Kristen Stewart, Robert Pattinson, Taylor Laut...
# 86  Daniel Radcliffe, Harry Melling, Jason Boyd, R...
# 87  Georgie Henley, Skandar Keynes, William Mosele...
# 88  Henry Cavill, Amy Adams, Michael Shannon, Dian...
# 89  Mark Hamill, Harrison Ford, Carrie Fisher, Bil...
# 90  Eric Sykes, Timothy Spall, David Tennant, Dani...
# 91  John Goodman, Billy Crystal, Mary Gibbs, Steve...
# 92  Macaulay Culkin, Joe Pesci, Daniel Stern, John...
# 93  Jennifer Lawrence, Josh Hutcherson, Liam Hemsw...
# 94  Ray Anthony, Christine Anu, Andy Arness, Alima...
# 95  Taylor Lautner, Gil Birmingham, Billy Burke, S...
# 96  Robert De Niro, Ben Stiller, Dustin Hoffman, B...
# 97  Bradley Cooper, Ed Helms, Zach Galifianakis, J...
# 98  Sandra Bullock, George Clooney, Ed Harris, Ort...
# 99  Matthew McConaughey, Reese Witherspoon, Seth M...
#
#                                                writer  \
# 0                                                 N/A
# 1                                       James Cameron
# 2   Ryan Coogler, Joe Robert Cole, Stan Lee (based...
# 3   Christopher Markus (screenplay by), Stephen Mc...
# 4                                       James Cameron
# 5   Rick Jaffa (screenplay by), Amanda Silver (scr...
# 6   Joss Whedon (screenplay), Zak Penn (story), Jo...
# 7   Rian Johnson, George Lucas (based on character...
# 8                                           Brad Bird
# 9   Jonathan Nolan (screenplay), Christopher Nolan...
# 10  Chris Weitz (screenplay by), Tony Gilroy (scre...
# 11  Stephen Chbosky (screenplay by), Evan Spilioto...
# 12  Andrew Stanton (original story by), Andrew Sta...
# 13                                       George Lucas
# 14                                       George Lucas
# 15  Joss Whedon, Stan Lee (based on the Marvel com...
# 16  Jonathan Nolan (screenplay), Christopher Nolan...
# 17  William Steig (based upon the book by), Andrew...
# 18                                   Melissa Mathison
# 19  Simon Beaufoy (screenplay), Michael Arndt (scr...
# 20  Ted Elliott, Terry Rossio, Ted Elliott (charac...
# 21  Irene Mecchi (screenplay by), Jonathan Roberts...
# 22  Derek Connolly, Colin Trevorrow, Michael Crich...
# 23  John Lasseter (story by), Andrew Stanton (stor...
# 24  Allan Heinberg (screenplay by), Zack Snyder (s...
# 25  Drew Pearce (screenplay by), Shane Black (scre...
# 26  Christopher Markus (screenplay by), Stephen Mc...
# 27  Gary Ross (screenplay), Suzanne Collins (scree...
# 28  Chris McKenna (screenplay by), Erik Sommers (s...
# 29  Stan Lee (Marvel comic book), Steve Ditko (Mar...
# ..                                                ...
# 70  George Lucas (screenplay by), Jonathan Hales (...
# 71  Ted Elliott, Terry Rossio, Ted Elliott (charac...
# 72  Lawrence Kasdan (screenplay by), George Lucas ...
# 73                       Dean Devlin, Roland Emmerich
# 74  Ted Elliott (screen story), Terry Rossio (scre...
# 75  Neal Purvis, Robert Wade, John Logan, Ian Flem...
# 76  Fran Walsh (screenplay), Philippa Boyens (scre...
# 77    Steve Kloves (screenplay), J.K. Rowling (novel)
# 78  Melissa Rosenberg (screenplay), Stephenie Meye...
# 79  Melissa Rosenberg (screenplay), Stephenie Meye...
# 80    Steve Kloves (screenplay), J.K. Rowling (novel)
# 81  David Leslie Johnson-McGoldrick (screenplay by...
# 82                                 M. Night Shyamalan
# 83  Pete Docter (story by), Bob Peterson (story by...
# 84                                  Christopher Nolan
# 85  Melissa Rosenberg (screenplay), Stephenie Meye...
# 86  Michael Goldenberg (screenplay), J.K. Rowling ...
# 87  Ann Peacock (screenplay), Andrew Adamson (scre...
# 88  David S. Goyer (screenplay), David S. Goyer (s...
# 89  Leigh Brackett (screenplay by), Lawrence Kasda...
# 90    Steve Kloves (screenplay), J.K. Rowling (novel)
# 91  Pete Docter (original story by), Jill Culton (...
# 92                                        John Hughes
# 93  Peter Craig (screenplay), Danny Strong (screen...
# 94  Lilly Wachowski, Lana Wachowski, Lilly Wachows...
# 95  Melissa Rosenberg (screenplay), Stephenie Meye...
# 96  Greg Glienna (characters), Mary Ruth Clarke (c...
# 97                             Jon Lucas, Scott Moore
# 98                       Alfonso Cuarón, Jonás Cuarón
# 99                                     Garth Jennings
#
#                                              language  \
# 0                                             English
# 1                                    English, Spanish
# 2               Swahili, Nama, English, Xhosa, Korean
# 3                                             English
# 4                                    English, Swedish
# 5                                             English
# 6                             English, Russian, Hindi
# 7                                             English
# 8                                             English
# 9                                   English, Mandarin
# 10                                            English
# 11                                            English
# 12                                English, Indonesian
# 13                                            English
# 14                                            English
# 15                                    English, Korean
# 16                                    English, Arabic
# 17                                            English
# 18                                            English
# 19                                            English
# 20          English, Turkish, Greek, Mandarin, French
# 21                      English, Swahili, Xhosa, Zulu
# 22                                   English, Russian
# 23                                   English, Spanish
# 24  English, German, Dutch, French, Spanish, Chine...
# 25                                            English
# 26   English, German, Xhosa, Russian, Romanian, Hindi
# 27                                            English
# 28                                            English
# 29                                            English
# ..                                                ...
# 70                                            English
# 71                                            English
# 72                                            English
# 73                                            English
# 74                                            English
# 75                                   English, Turkish
# 76                                            English
# 77                                            English
# 78                                            English
# 79                                   English, Italian
# 80                                            English
# 81                                            English
# 82                            English, Latin, Spanish
# 83                                            English
# 84                          English, Japanese, French
# 85                                            English
# 86                                            English
# 87           English, German, Brazilian Sign Language
# 88                                            English
# 89                                            English
# 90                                    English, French
# 91                                            English
# 92                                            English
# 93                                            English
# 94                                    English, French
# 95                                English, Portuguese
# 96                           English, Spanish, Hebrew
# 97                                            English
# 98                               English, Greenlandic
# 99                       English, Japanese, Ukrainian
#
#                                       country  \
# 0                                         USA
# 1                                     UK, USA
# 2   USA, South Africa, South Korea, Australia
# 3                                         USA
# 4                                         USA
# 5                                         USA
# 6                                         USA
# 7                                         USA
# 8                                         USA
# 9                                     USA, UK
# 10                                        USA
# 11                                    USA, UK
# 12                                        USA
# 13                                        USA
# 14                                        USA
# 15                                        USA
# 16                                    UK, USA
# 17                                        USA
# 18                                        USA
# 19                                        USA
# 20                                        USA
# 21                                        USA
# 22                                        USA
# 23                                        USA
# 24                      USA, China, Hong Kong
# 25                                 China, USA
# 26                               USA, Germany
# 27                                        USA
# 28                                        USA
# 29                                        USA
# ..                                        ...
# 70                                        USA
# 71                                        USA
# 72                                        USA
# 73                                        USA
# 74                                        USA
# 75                                    UK, USA
# 76                           USA, New Zealand
# 77                                    UK, USA
# 78                                        USA
# 79                                        USA
# 80                                    UK, USA
# 81                             Australia, USA
# 82                                        USA
# 83                                        USA
# 84                                    USA, UK
# 85                                        USA
# 86                                    UK, USA
# 87                                    USA, UK
# 88                                    USA, UK
# 89                                        USA
# 90                                    UK, USA
# 91                                        USA
# 92                                        USA
# 93                               Germany, USA
# 94                                        USA
# 95                                        USA
# 96                                        USA
# 97                               USA, Germany
# 98                                    UK, USA
# 99                                 Japan, USA
#
#                                                awards imdbRating  imdbVotes  \
# 0                                                 N/A        N/A        N/A
# 1    Won 3 Oscars. Another 85 wins & 128 nominations.        7.8  1,013,715
# 2                                     14 nominations.        7.4    430,289
# 3                                                 N/A        8.5    550,743
# 4   Won 11 Oscars. Another 111 wins & 77 nominations.        7.8    926,635
# 5                           14 wins & 57 nominations.        7.0    525,152
# 6   Nominated for 1 Oscar. Another 38 wins & 79 no...        8.1  1,136,922
# 7   Nominated for 4 Oscars. Another 12 wins & 71 n...        7.2    438,214
# 8                                                 N/A        7.8    159,661
# 9   Won 2 Oscars. Another 152 wins & 155 nominations.        9.0  2,005,606
# 10  Nominated for 2 Oscars. Another 23 wins & 78 n...        7.8    457,611
# 11  Nominated for 2 Oscars. Another 12 wins & 65 n...        7.2    226,098
# 12  Nominated for 1 BAFTA Film Award. Another 15 w...        7.3    203,507
# 13  Nominated for 3 Oscars. Another 26 wins & 65 n...        6.5    635,302
# 14    Won 6 Oscars. Another 50 wins & 28 nominations.        8.6  1,092,532
# 15                           7 wins & 45 nominations.        7.4    619,549
# 16  Nominated for 1 BAFTA Film Award. Another 38 w...        8.4  1,352,041
# 17  Nominated for 2 Oscars. Another 18 wins & 50 n...        7.2    370,258
# 18    Won 4 Oscars. Another 47 wins & 34 nominations.        7.9    328,437
# 19  Nominated for 1 Golden Globe. Another 22 wins ...        7.5    564,437
# 20     Won 1 Oscar. Another 42 wins & 53 nominations.        7.3    601,107
# 21    Won 2 Oscars. Another 33 wins & 29 nominations.        8.5    807,335
# 22                                                N/A        6.2    187,929
# 23    Won 2 Oscars. Another 58 wins & 91 nominations.        8.3    662,598
# 24                          17 wins & 54 nominations.        7.5    459,915
# 25  Nominated for 1 Oscar. Another 17 wins & 61 no...        7.2    662,530
# 26                          16 wins & 65 nominations.        7.8    538,908
# 27  Nominated for 1 Golden Globe. Another 33 wins ...        7.2    780,442
# 28                            2 wins & 3 nominations.        7.0    224,894
# 29  Nominated for 2 Oscars. Another 16 wins & 58 n...        7.3    623,678
# ..                                                ...        ...        ...
# 70  Nominated for 1 Oscar. Another 16 wins & 58 no...        6.6    559,024
# 71  Nominated for 2 Oscars. Another 20 wins & 44 n...        7.1    545,204
# 72  Nominated for 4 Oscars. Another 20 wins & 16 n...        8.3    837,046
# 73     Won 1 Oscar. Another 34 wins & 34 nominations.        7.0    484,537
# 74  Nominated for 5 Oscars. Another 36 wins & 96 n...        8.0    944,014
# 75   Won 2 Oscars. Another 65 wins & 119 nominations.        7.8    582,802
# 76  Nominated for 3 Oscars. Another 10 wins & 72 n...        7.9    709,013
# 77  Nominated for 1 Oscar. Another 8 wins & 35 nom...        7.6    402,648
# 78                          22 wins & 34 nominations.        5.0    207,159
# 79                          20 wins & 24 nominations.        4.7    243,897
# 80  Nominated for 2 Oscars. Another 15 wins & 53 n...        7.7    407,896
# 81                                                N/A        7.9     24,893
# 82  Nominated for 6 Oscars. Another 32 wins & 48 n...        8.1    826,417
# 83    Won 2 Oscars. Another 74 wins & 81 nominations.        8.3    821,327
# 84  Won 4 Oscars. Another 152 wins & 204 nominations.        8.8  1,779,523
# 85                          21 wins & 14 nominations.        5.5    210,369
# 86  Nominated for 2 BAFTA Film Awards. Another 14 ...        7.5    436,741
# 87     Won 1 Oscar. Another 14 wins & 46 nominations.        6.9    331,570
# 88                           7 wins & 46 nominations.        7.1    629,830
# 89     Won 1 Oscar. Another 21 wins & 19 nominations.        8.8  1,021,079
# 90  Nominated for 1 Oscar. Another 13 wins & 42 no...        7.7    474,003
# 91     Won 1 Oscar. Another 13 wins & 38 nominations.        8.1    718,325
# 92  Nominated for 2 Oscars. Another 10 wins & 4 no...        7.5    393,574
# 93                          17 wins & 34 nominations.        6.6    241,696
# 94                           8 wins & 31 nominations.        7.2    469,313
# 95                          11 wins & 22 nominations.        4.9    204,370
# 96                            2 wins & 7 nominations.        6.3    233,894
# 97  Won 1 Golden Globe. Another 12 wins & 25 nomin...        7.7    656,156
# 98  Won 7 Oscars. Another 232 wins & 175 nominations.        7.7    685,873
# 99  Nominated for 2 Golden Globes. Another 2 wins ...        7.1    109,383
#
#       box_office                           studio
# 0            N/A                              N/A
# 1   $749,700,000                 20th Century Fox
# 2   $501,105,037                   Marvel Studios
# 3   $664,987,816             Walt Disney Pictures
# 4            N/A               Paramount Pictures
# 5   $528,757,749               Universal Pictures
# 6   $623,279,547             Walt Disney Pictures
# 7   $619,117,636             Walt Disney Pictures
# 8            N/A                     Disney/Pixar
# 9   $533,316,061  Warner Bros. Pictures/Legendary
# 10  $532,171,696             Walt Disney Pictures
# 11  $503,974,884             Walt Disney Pictures
# 12  $486,292,984       Walt Disney Pictures/PIXAR
# 13  $431,000,000                 20th Century Fox
# 14           N/A                 20th Century Fox
# 15  $429,113,729             Walt Disney Pictures
# 16  $448,130,642            Warner Bros. Pictures
# 17  $436,471,036                   DreamWorks SKG
# 18           N/A               Universal Pictures
# 19  $336,663,349                  Lionsgate Films
# 20  $423,032,628                      Buena Vista
# 21   $94,240,635                      Buena Vista
# 22           N/A               Universal Pictures
# 23  $414,984,497             Walt Disney Pictures
# 24  $412,400,625            Warner Bros. Pictures
# 25  $408,992,272             Walt Disney Pictures
# 26  $408,080,554             Walt Disney Pictures
# 27  $407,981,652                        Lionsgate
# 28  $393,201,353                Columbia Pictures
# 29  $403,706,375                Columbia Pictures
# ..           ...                              ...
# 70  $307,900,000                 20th Century Fox
# 71  $309,404,152                      Buena Vista
# 72           N/A            Twentieth Century Fox
# 73           N/A                 20th Century Fox
# 74  $305,343,252             Buena Vista Pictures
# 75  $299,300,000                              MGM
# 76  $303,001,229                     Warner Bros.
# 77  $301,920,409            Warner Bros. Pictures
# 78  $300,523,113             Summit Entertainment
# 79  $296,593,070             Summit Entertainment
# 80  $294,980,434            Warner Bros. Pictures
# 81           N/A            Warner Bros. Pictures
# 82           N/A            Hollywood/Buena Vista
# 83  $292,979,556             Walt Disney Pictures
# 84  $292,568,851            Warner Bros. Pictures
# 85  $292,298,923   Lionsgate/Summit Entertainment
# 86  $291,980,108            Warner Bros. Pictures
# 87  $291,685,219                      Buena Vista
# 88  $291,021,565            Warner Bros. Pictures
# 89    $4,548,170            Twentieth Century Fox
# 90  $289,994,397            Warner Bros. Pictures
# 91   $34,034,168   Buena Vista Distribution Compa
# 92           N/A            Twentieth Century Fox
# 93  $254,641,329                  Lionsgate Films
# 94  $281,500,000            Warner Bros. Pictures
# 95  $281,267,663             Summit Entertainment
# 96  $279,167,575               Universal Pictures
# 97  $277,313,371            Warner Bros. Pictures
# 98  $274,084,951            Warner Bros. Pictures
# 99  $270,322,940       Illumination Entertainment
#
# [100 rows x 17 columns]

# %% [markdown]
# <h2>Insert Into MongoDB

# %%
import pymongo
conn = "mongodb://127.0.0.1:27017"
client = pymongo.MongoClient(conn)
db = client["movies"]
db.imdb.insert_many(imdb_dicts)
imdb_data = db.imdb.find()
for data in imdb_data:
    pprint(data)
# Out:
# {'_id': ObjectId('5c42a38eb520d90c43bccf0e'),
#  'awards': 'N/A',
#  'box_office': 'N/A',
#  'country': 'USA',
#  'director': 'N/A',
#  'genre': 'Short',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A',
#  'language': 'English',
#  'main_cast': 'Freddie Kuguru',
#  'studio': 'N/A',
#  'title': 'Star Wars: Episode VII - Toys',
#  'writer': 'N/A',
#  'year': '2015'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf0f'),
#  'awards': 'Won 3 Oscars. Another 85 wins & 128 nominations.',
#  'box_office': '$749,700,000',
#  'country': 'UK, USA',
#  'director': 'James Cameron',
#  'genre': 'Action, Adventure, Fantasy, Sci-Fi',
#  'imdbRating': '7.8',
#  'imdbVotes': '1,013,715',
#  'language': 'English, Spanish',
#  'main_cast': 'Sam Worthington, Zoe Saldana, Sigourney Weaver, Stephen Lang',
#  'studio': '20th Century Fox',
#  'title': 'Avatar',
#  'writer': 'James Cameron',
#  'year': '2009'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf10'),
#  'awards': '14 nominations.',
#  'box_office': '$501,105,037',
#  'country': 'USA, South Africa, South Korea, Australia',
#  'director': 'Ryan Coogler',
#  'genre': 'Action, Adventure, Sci-Fi',
#  'imdbRating': '7.4',
#  'imdbVotes': '430,289',
#  'language': 'Swahili, Nama, English, Xhosa, Korean',
#  'main_cast': "Chadwick Boseman, Michael B. Jordan, Lupita Nyong'o, Danai "
#               'Gurira',
#  'studio': 'Marvel Studios',
#  'title': 'Black Panther',
#  'writer': 'Ryan Coogler, Joe Robert Cole, Stan Lee (based on the Marvel '
#            'comics by), Jack Kirby (based on the Marvel Comics by)',
#  'year': '2018'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf11'),
#  'awards': 'N/A',
#  'box_office': '$664,987,816',
#  'country': 'USA',
#  'director': 'Anthony Russo, Joe Russo',
#  'genre': 'Action, Adventure, Fantasy, Sci-Fi',
#  'imdbRating': '8.5',
#  'imdbVotes': '550,743',
#  'language': 'English',
#  'main_cast': 'Robert Downey Jr., Chris Hemsworth, Mark Ruffalo, Chris Evans',
#  'studio': 'Walt Disney Pictures',
#  'title': 'Avengers: Infinity War',
#  'writer': 'Christopher Markus (screenplay by), Stephen McFeely (screenplay '
#            'by), Stan Lee (based on the Marvel comics by), Jack Kirby (based '
#            'on the Marvel comics by), Joe Simon (Captain America created by), '
#            'Jack Kirby (Captain America created by), Steve Englehart '
#            '(Star-Lord created by), Steve Gan (Star-Lord created by), Bill '
#            'Mantlo (Rocket Raccoon created by), Keith Giffen (Rocket Raccoon '
#            'created by), Jim Starlin (Thanos,  Gamora and Drax created by), '
#            'Stan Lee (Groot created by), Larry Lieber (Groot created by), Jack '
#            'Kirby (Groot created by), Steve Englehart (Mantis created by), Don '
#            'Heck (Mantis created by)',
#  'year': '2018'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf12'),
#  'awards': 'Won 11 Oscars. Another 111 wins & 77 nominations.',
#  'box_office': 'N/A',
#  'country': 'USA',
#  'director': 'James Cameron',
#  'genre': 'Drama, Romance',
#  'imdbRating': '7.8',
#  'imdbVotes': '926,635',
#  'language': 'English, Swedish',
#  'main_cast': 'Leonardo DiCaprio, Kate Winslet, Billy Zane, Kathy Bates',
#  'studio': 'Paramount Pictures',
#  'title': 'Titanic',
#  'writer': 'James Cameron',
#  'year': '1997'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf13'),
#  'awards': '14 wins & 57 nominations.',
#  'box_office': '$528,757,749',
#  'country': 'USA',
#  'director': 'Colin Trevorrow',
#  'genre': 'Action, Adventure, Sci-Fi',
#  'imdbRating': '7.0',
#  'imdbVotes': '525,152',
#  'language': 'English',
#  'main_cast': 'Chris Pratt, Bryce Dallas Howard, Irrfan Khan, Vincent '
#               "D'Onofrio",
#  'studio': 'Universal Pictures',
#  'title': 'Jurassic World',
#  'writer': 'Rick Jaffa (screenplay by), Amanda Silver (screenplay by), Colin '
#            'Trevorrow (screenplay by), Derek Connolly (screenplay by), Rick '
#            'Jaffa (story by), Amanda Silver (story by), Michael Crichton '
#            '(based on the characters created by)',
#  'year': '2015'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf14'),
#  'awards': 'Nominated for 1 Oscar. Another 38 wins & 79 nominations.',
#  'box_office': '$623,279,547',
#  'country': 'USA',
#  'director': 'Joss Whedon',
#  'genre': 'Action, Adventure, Sci-Fi',
#  'imdbRating': '8.1',
#  'imdbVotes': '1,136,922',
#  'language': 'English, Russian, Hindi',
#  'main_cast': 'Robert Downey Jr., Chris Evans, Mark Ruffalo, Chris Hemsworth',
#  'studio': 'Walt Disney Pictures',
#  'title': 'The Avengers',
#  'writer': 'Joss Whedon (screenplay), Zak Penn (story), Joss Whedon (story)',
#  'year': '2012'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf15'),
#  'awards': 'Nominated for 4 Oscars. Another 12 wins & 71 nominations.',
#  'box_office': '$619,117,636',
#  'country': 'USA',
#  'director': 'Rian Johnson',
#  'genre': 'Action, Adventure, Fantasy, Sci-Fi',
#  'imdbRating': '7.2',
#  'imdbVotes': '438,214',
#  'language': 'English',
#  'main_cast': 'Mark Hamill, Carrie Fisher, Adam Driver, Daisy Ridley',
#  'studio': 'Walt Disney Pictures',
#  'title': 'Star Wars: Episode VIII - The Last Jedi',
#  'writer': 'Rian Johnson, George Lucas (based on characters created by)',
#  'year': '2017'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf16'),
#  'awards': 'N/A',
#  'box_office': 'N/A',
#  'country': 'USA',
#  'director': 'Brad Bird',
#  'genre': 'Animation, Action, Adventure, Comedy, Family, Sci-Fi',
#  'imdbRating': '7.8',
#  'imdbVotes': '159,661',
#  'language': 'English',
#  'main_cast': 'Craig T. Nelson, Holly Hunter, Sarah Vowell, Huck Milner',
#  'studio': 'Disney/Pixar',
#  'title': 'Incredibles 2',
#  'writer': 'Brad Bird',
#  'year': '2018'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf17'),
#  'awards': 'Won 2 Oscars. Another 152 wins & 155 nominations.',
#  'box_office': '$533,316,061',
#  'country': 'USA, UK',
#  'director': 'Christopher Nolan',
#  'genre': 'Action, Crime, Drama, Thriller',
#  'imdbRating': '9.0',
#  'imdbVotes': '2,005,606',
#  'language': 'English, Mandarin',
#  'main_cast': 'Christian Bale, Heath Ledger, Aaron Eckhart, Michael Caine',
#  'studio': 'Warner Bros. Pictures/Legendary',
#  'title': 'The Dark Knight',
#  'writer': 'Jonathan Nolan (screenplay), Christopher Nolan (screenplay), '
#            'Christopher Nolan (story), David S. Goyer (story), Bob Kane '
#            '(characters)',
#  'year': '2008'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf18'),
#  'awards': 'Nominated for 2 Oscars. Another 23 wins & 78 nominations.',
#  'box_office': '$532,171,696',
#  'country': 'USA',
#  'director': 'Gareth Edwards',
#  'genre': 'Action, Adventure, Sci-Fi',
#  'imdbRating': '7.8',
#  'imdbVotes': '457,611',
#  'language': 'English',
#  'main_cast': 'Felicity Jones, Diego Luna, Alan Tudyk, Donnie Yen',
#  'studio': 'Walt Disney Pictures',
#  'title': 'Rogue One: A Star Wars Story',
#  'writer': 'Chris Weitz (screenplay by), Tony Gilroy (screenplay by), John '
#            'Knoll (story by), Gary Whitta (story by), George Lucas (based on '
#            'characters created by)',
#  'year': '2016'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf19'),
#  'awards': 'Nominated for 2 Oscars. Another 12 wins & 65 nominations.',
#  'box_office': '$503,974,884',
#  'country': 'USA, UK',
#  'director': 'Bill Condon',
#  'genre': 'Family, Fantasy, Musical, Romance',
#  'imdbRating': '7.2',
#  'imdbVotes': '226,098',
#  'language': 'English',
#  'main_cast': 'Emma Watson, Dan Stevens, Luke Evans, Josh Gad',
#  'studio': 'Walt Disney Pictures',
#  'title': 'Beauty and the Beast',
#  'writer': 'Stephen Chbosky (screenplay by), Evan Spiliotopoulos (screenplay '
#            'by), Linda Woolverton (based on the 1991 animated film "Beauty and '
#            'the Beast" animation screenplay by)',
#  'year': '2017'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf1a'),
#  'awards': 'Nominated for 1 BAFTA Film Award. Another 15 wins & 42 '
#            'nominations.',
#  'box_office': '$486,292,984',
#  'country': 'USA',
#  'director': 'Andrew Stanton, Angus MacLane(co-director)',
#  'genre': 'Animation, Adventure, Comedy, Family',
#  'imdbRating': '7.3',
#  'imdbVotes': '203,507',
#  'language': 'English, Indonesian',
#  'main_cast': "Ellen DeGeneres, Albert Brooks, Ed O'Neill, Kaitlin Olson",
#  'studio': 'Walt Disney Pictures/PIXAR',
#  'title': 'Finding Dory',
#  'writer': 'Andrew Stanton (original story by), Andrew Stanton (screenplay '
#            'by), Victoria Strouse (screenplay by), Bob Peterson (additional '
#            'screenplay material by), Angus MacLane (additional story material '
#            'by)',
#  'year': '2016'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf1b'),
#  'awards': 'Nominated for 3 Oscars. Another 26 wins & 65 nominations.',
#  'box_office': '$431,000,000',
#  'country': 'USA',
#  'director': 'George Lucas',
#  'genre': 'Action, Adventure, Fantasy, Sci-Fi',
#  'imdbRating': '6.5',
#  'imdbVotes': '635,302',
#  'language': 'English',
#  'main_cast': 'Liam Neeson, Ewan McGregor, Natalie Portman, Jake Lloyd',
#  'studio': '20th Century Fox',
#  'title': 'Star Wars: Episode I - The Phantom Menace',
#  'writer': 'George Lucas',
#  'year': '1999'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf1c'),
#  'awards': 'Won 6 Oscars. Another 50 wins & 28 nominations.',
#  'box_office': 'N/A',
#  'country': 'USA',
#  'director': 'George Lucas',
#  'genre': 'Action, Adventure, Fantasy, Sci-Fi',
#  'imdbRating': '8.6',
#  'imdbVotes': '1,092,532',
#  'language': 'English',
#  'main_cast': 'Mark Hamill, Harrison Ford, Carrie Fisher, Peter Cushing',
#  'studio': '20th Century Fox',
#  'title': 'Star Wars: Episode IV - A New Hope',
#  'writer': 'George Lucas',
#  'year': '1977'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf1d'),
#  'awards': '7 wins & 45 nominations.',
#  'box_office': '$429,113,729',
#  'country': 'USA',
#  'director': 'Joss Whedon',
#  'genre': 'Action, Adventure, Sci-Fi',
#  'imdbRating': '7.4',
#  'imdbVotes': '619,549',
#  'language': 'English, Korean',
#  'main_cast': 'Robert Downey Jr., Chris Hemsworth, Mark Ruffalo, Chris Evans',
#  'studio': 'Walt Disney Pictures',
#  'title': 'Avengers: Age of Ultron',
#  'writer': 'Joss Whedon, Stan Lee (based on the Marvel comics by), Jack Kirby '
#            '(based on the Marvel comics by), Joe Simon (character created by: '
#            'Captain America), Jack Kirby (character created by: Captain '
#            'America), Jim Starlin (character created by: Thanos)',
#  'year': '2015'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf1e'),
#  'awards': 'Nominated for 1 BAFTA Film Award. Another 38 wins & 102 '
#            'nominations.',
#  'box_office': '$448,130,642',
#  'country': 'UK, USA',
#  'director': 'Christopher Nolan',
#  'genre': 'Action, Thriller',
#  'imdbRating': '8.4',
#  'imdbVotes': '1,352,041',
#  'language': 'English, Arabic',
#  'main_cast': 'Christian Bale, Gary Oldman, Tom Hardy, Joseph Gordon-Levitt',
#  'studio': 'Warner Bros. Pictures',
#  'title': 'The Dark Knight Rises',
#  'writer': 'Jonathan Nolan (screenplay), Christopher Nolan (screenplay), '
#            'Christopher Nolan (story), David S. Goyer (story), Bob Kane '
#            '(characters)',
#  'year': '2012'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf1f'),
#  'awards': 'Nominated for 2 Oscars. Another 18 wins & 50 nominations.',
#  'box_office': '$436,471,036',
#  'country': 'USA',
#  'director': 'Andrew Adamson, Kelly Asbury, Conrad Vernon',
#  'genre': 'Animation, Adventure, Comedy, Family, Fantasy, Romance',
#  'imdbRating': '7.2',
#  'imdbVotes': '370,258',
#  'language': 'English',
#  'main_cast': 'Mike Myers, Eddie Murphy, Cameron Diaz, Julie Andrews',
#  'studio': 'DreamWorks SKG',
#  'title': 'Shrek 2',
#  'writer': 'William Steig (based upon the book by), Andrew Adamson (story by), '
#            'Andrew Adamson (screenplay by), Joe Stillman (screenplay by), J. '
#            'David Stem (screenplay by), David N. Weiss (screenplay by), Cody '
#            'Cameron (additional dialogue), Walt Dohrn (additional dialogue), '
#            'Chris Miller (additional dialogue), David P. Smith (additional '
#            'dialogue), Conrad Vernon (additional dialogue)',
#  'year': '2004'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf20'),
#  'awards': 'Won 4 Oscars. Another 47 wins & 34 nominations.',
#  'box_office': 'N/A',
#  'country': 'USA',
#  'director': 'Steven Spielberg',
#  'genre': 'Family, Sci-Fi',
#  'imdbRating': '7.9',
#  'imdbVotes': '328,437',
#  'language': 'English',
#  'main_cast': 'Dee Wallace, Henry Thomas, Peter Coyote, Robert MacNaughton',
#  'studio': 'Universal Pictures',
#  'title': 'E.T. The Extra-Terrestrial',
#  'writer': 'Melissa Mathison',
#  'year': '1982'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf21'),
#  'awards': 'Nominated for 1 Golden Globe. Another 22 wins & 66 nominations.',
#  'box_office': '$336,663,349',
#  'country': 'USA',
#  'director': 'Francis Lawrence',
#  'genre': 'Action, Adventure, Sci-Fi, Thriller',
#  'imdbRating': '7.5',
#  'imdbVotes': '564,437',
#  'language': 'English',
#  'main_cast': 'Jennifer Lawrence, Liam Hemsworth, Jack Quaid, Taylor St. Clair',
#  'studio': 'Lionsgate Films',
#  'title': 'The Hunger Games: Catching Fire',
#  'writer': 'Simon Beaufoy (screenplay), Michael Arndt (screenplay), Suzanne '
#            'Collins (novel)',
#  'year': '2013'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf22'),
#  'awards': 'Won 1 Oscar. Another 42 wins & 53 nominations.',
#  'box_office': '$423,032,628',
#  'country': 'USA',
#  'director': 'Gore Verbinski',
#  'genre': 'Action, Adventure, Fantasy',
#  'imdbRating': '7.3',
#  'imdbVotes': '601,107',
#  'language': 'English, Turkish, Greek, Mandarin, French',
#  'main_cast': 'Johnny Depp, Orlando Bloom, Keira Knightley, Jack Davenport',
#  'studio': 'Buena Vista',
#  'title': "Pirates of the Caribbean: Dead Man's Chest",
#  'writer': 'Ted Elliott, Terry Rossio, Ted Elliott (characters), Terry Rossio '
#            '(characters), Stuart Beattie (characters), Jay Wolpert '
#            '(characters)',
#  'year': '2006'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf23'),
#  'awards': 'Won 2 Oscars. Another 33 wins & 29 nominations.',
#  'box_office': '$94,240,635',
#  'country': 'USA',
#  'director': 'Roger Allers, Rob Minkoff',
#  'genre': 'Animation, Adventure, Drama, Family, Musical',
#  'imdbRating': '8.5',
#  'imdbVotes': '807,335',
#  'language': 'English, Swahili, Xhosa, Zulu',
#  'main_cast': 'Rowan Atkinson, Matthew Broderick, Niketa Calame-Harris, Jim '
#               'Cummings',
#  'studio': 'Buena Vista',
#  'title': 'The Lion King',
#  'writer': 'Irene Mecchi (screenplay by), Jonathan Roberts (screenplay by), '
#            'Linda Woolverton (screenplay by), Burny Mattinson (story), Barry '
#            'Johnson (story), Lorna Cook (story), Thom Enriquez (story), Andy '
#            'Gaskill (story), Gary Trousdale (story), Jim Capobianco (story), '
#            'Kevin Harkey (story), Jorgen Klubien (story), Chris Sanders '
#            '(story), Tom Sito (story), Larry Leker (story), Joe Ranft (story), '
#            'Rick Maki (story), Ed Gombert (story), Francis Glebas (story), '
#            'Mark Kausler (story), J.T. Allen (additional story material), '
#            'George Scribner (additional story material), Miguel Tejada-Flores '
#            '(additional story material), Jenny Tripp (additional story '
#            'material), Bob Tzudiker (additional story material), Christopher '
#            'Vogler (additional story material), Kirk Wise (additional story '
#            'material), Noni White (additional story material), Brenda Chapman '
#            '(story supervisor)',
#  'year': '1994'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf24'),
#  'awards': 'N/A',
#  'box_office': 'N/A',
#  'country': 'USA',
#  'director': 'J.A. Bayona',
#  'genre': 'Action, Adventure, Sci-Fi',
#  'imdbRating': '6.2',
#  'imdbVotes': '187,929',
#  'language': 'English, Russian',
#  'main_cast': 'Chris Pratt, Bryce Dallas Howard, Rafe Spall, Justice Smith',
#  'studio': 'Universal Pictures',
#  'title': 'Jurassic World: Fallen Kingdom',
#  'writer': 'Derek Connolly, Colin Trevorrow, Michael Crichton (based on '
#            'characters created by)',
#  'year': '2018'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf25'),
#  'awards': 'Won 2 Oscars. Another 58 wins & 91 nominations.',
#  'box_office': '$414,984,497',
#  'country': 'USA',
#  'director': 'Lee Unkrich',
#  'genre': 'Animation, Adventure, Comedy, Family, Fantasy',
#  'imdbRating': '8.3',
#  'imdbVotes': '662,598',
#  'language': 'English, Spanish',
#  'main_cast': 'Tom Hanks, Tim Allen, Joan Cusack, Ned Beatty',
#  'studio': 'Walt Disney Pictures',
#  'title': 'Toy Story 3',
#  'writer': 'John Lasseter (story by), Andrew Stanton (story by), Lee Unkrich '
#            '(story by), Michael Arndt (screenplay by)',
#  'year': '2010'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf26'),
#  'awards': '17 wins & 54 nominations.',
#  'box_office': '$412,400,625',
#  'country': 'USA, China, Hong Kong',
#  'director': 'Patty Jenkins',
#  'genre': 'Action, Adventure, Fantasy, Sci-Fi, War',
#  'imdbRating': '7.5',
#  'imdbVotes': '459,915',
#  'language': 'English, German, Dutch, French, Spanish, Chinese, Greek,  '
#              'Ancient (to 1453), North American Indian',
#  'main_cast': 'Gal Gadot, Chris Pine, Connie Nielsen, Robin Wright',
#  'studio': 'Warner Bros. Pictures',
#  'title': 'Wonder Woman',
#  'writer': 'Allan Heinberg (screenplay by), Zack Snyder (story by), Allan '
#            'Heinberg (story by), Jason Fuchs (story by), William Moulton '
#            'Marston (Wonder Woman created by)',
#  'year': '2017'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf27'),
#  'awards': 'Nominated for 1 Oscar. Another 17 wins & 61 nominations.',
#  'box_office': '$408,992,272',
#  'country': 'China, USA',
#  'director': 'Shane Black',
#  'genre': 'Action, Adventure, Sci-Fi',
#  'imdbRating': '7.2',
#  'imdbVotes': '662,530',
#  'language': 'English',
#  'main_cast': 'Robert Downey Jr., Gwyneth Paltrow, Don Cheadle, Guy Pearce',
#  'studio': 'Walt Disney Pictures',
#  'title': 'Iron Man 3',
#  'writer': 'Drew Pearce (screenplay by), Shane Black (screenplay by), Stan Lee '
#            '(based on the Marvel comic book by), Don Heck (based on the Marvel '
#            'comic book by), Larry Lieber (based on the Marvel comic book by), '
#            'Jack Kirby (based on the Marvel comic book by), Warren Ellis '
#            '(based on the "Extremis" mini-series written by), Adi Granov '
#            '(based on the "Extremis" mini-series illustrated by)',
#  'year': '2013'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf28'),
#  'awards': '16 wins & 65 nominations.',
#  'box_office': '$408,080,554',
#  'country': 'USA, Germany',
#  'director': 'Anthony Russo, Joe Russo',
#  'genre': 'Action, Adventure, Sci-Fi',
#  'imdbRating': '7.8',
#  'imdbVotes': '538,908',
#  'language': 'English, German, Xhosa, Russian, Romanian, Hindi',
#  'main_cast': 'Chris Evans, Robert Downey Jr., Scarlett Johansson, Sebastian '
#               'Stan',
#  'studio': 'Walt Disney Pictures',
#  'title': 'Captain America: Civil War',
#  'writer': 'Christopher Markus (screenplay by), Stephen McFeely (screenplay '
#            'by), Joe Simon (based on the Marvel comics by), Jack Kirby (based '
#            'on the Marvel comics by)',
#  'year': '2016'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf29'),
#  'awards': 'Nominated for 1 Golden Globe. Another 33 wins & 47 nominations.',
#  'box_office': '$407,981,652',
#  'country': 'USA',
#  'director': 'Gary Ross',
#  'genre': 'Action, Adventure, Sci-Fi, Thriller',
#  'imdbRating': '7.2',
#  'imdbVotes': '780,442',
#  'language': 'English',
#  'main_cast': 'Stanley Tucci, Wes Bentley, Jennifer Lawrence, Willow Shields',
#  'studio': 'Lionsgate',
#  'title': 'The Hunger Games',
#  'writer': 'Gary Ross (screenplay), Suzanne Collins (screenplay), Billy Ray '
#            '(screenplay), Suzanne Collins (novel)',
#  'year': '2012'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf2a'),
#  'awards': '2 wins & 3 nominations.',
#  'box_office': '$393,201,353',
#  'country': 'USA',
#  'director': 'Jake Kasdan',
#  'genre': 'Action, Adventure, Comedy, Fantasy',
#  'imdbRating': '7.0',
#  'imdbVotes': '224,894',
#  'language': 'English',
#  'main_cast': 'Dwayne Johnson, Kevin Hart, Jack Black, Karen Gillan',
#  'studio': 'Columbia Pictures',
#  'title': 'Jumanji: Welcome to the Jungle',
#  'writer': 'Chris McKenna (screenplay by), Erik Sommers (screenplay by), Scott '
#            'Rosenberg (screenplay by), Jeff Pinkner (screenplay by), Chris '
#            'McKenna (screen story by), Chris Van Allsburg (based on the book '
#            '"Jumanji" by), Greg Taylor (based on the film "Jumanji" screen '
#            'story by), Jim Strain (based on the film "Jumanji" screen story '
#            'by), Chris Van Allsburg (based on the film "Jumanji" screen story '
#            'by), Jonathan Hensleigh (based on the film "Jumanji" screenplay '
#            'by), Greg Taylor (based on the film "Jumanji" screenplay by), Jim '
#            'Strain (based on the film "Jumanji" screenplay by)',
#  'year': '2017'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf2b'),
#  'awards': 'Nominated for 2 Oscars. Another 16 wins & 58 nominations.',
#  'box_office': '$403,706,375',
#  'country': 'USA',
#  'director': 'Sam Raimi',
#  'genre': 'Action, Adventure, Sci-Fi',
#  'imdbRating': '7.3',
#  'imdbVotes': '623,678',
#  'language': 'English',
#  'main_cast': 'Tobey Maguire, Willem Dafoe, Kirsten Dunst, James Franco',
#  'studio': 'Columbia Pictures',
#  'title': 'Spider-Man',
#  'writer': 'Stan Lee (Marvel comic book), Steve Ditko (Marvel comic book), '
#            'David Koepp (screenplay)',
#  'year': '2002'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf2c'),
#  'awards': 'Nominated for 1 Oscar. Another 15 wins & 27 nominations.',
#  'box_office': '$402,076,689',
#  'country': 'USA',
#  'director': 'Michael Bay',
#  'genre': 'Action, Adventure, Sci-Fi',
#  'imdbRating': '6.0',
#  'imdbVotes': '358,871',
#  'language': 'English, Spanish',
#  'main_cast': 'Shia LaBeouf, Megan Fox, Josh Duhamel, Tyrese Gibson',
#  'studio': 'Paramount/Dreamworks',
#  'title': 'Transformers: Revenge of the Fallen',
#  'writer': 'Ehren Kruger, Roberto Orci, Alex Kurtzman',
#  'year': '2009'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf2d'),
#  'awards': 'Won 2 Oscars. Another 77 wins & 57 nominations.',
#  'box_office': '$400,736,600',
#  'country': 'USA',
#  'director': 'Chris Buck, Jennifer Lee',
#  'genre': 'Animation, Adventure, Comedy, Family, Fantasy, Musical',
#  'imdbRating': '7.5',
#  'imdbVotes': '503,447',
#  'language': 'English, Norwegian',
#  'main_cast': 'Kristen Bell, Idina Menzel, Jonathan Groff, Josh Gad',
#  'studio': 'Walt Disney Pictures',
#  'title': 'Frozen',
#  'writer': 'Jennifer Lee (screenplay by), Hans Christian Andersen (story '
#            'inspired by "The Snow Queen" by), Chris Buck (story by), Jennifer '
#            'Lee (story by), Shane Morris (story by)',
#  'year': '2013'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf2e'),
#  'awards': 'Won 3 Oscars. Another 32 wins & 25 nominations.',
#  'box_office': '$45,299,680',
#  'country': 'USA',
#  'director': 'Steven Spielberg',
#  'genre': 'Adventure, Sci-Fi, Thriller',
#  'imdbRating': '8.1',
#  'imdbVotes': '761,823',
#  'language': 'English, Spanish',
#  'main_cast': 'Sam Neill, Laura Dern, Jeff Goldblum, Richard Attenborough',
#  'studio': 'Universal City Studios',
#  'title': 'Jurassic Park',
#  'writer': 'Michael Crichton (novel), Michael Crichton (screenplay), David '
#            'Koepp (screenplay)',
#  'year': '1993'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf2f'),
#  'awards': 'Nominated for 1 Oscar. Another 12 wins & 42 nominations.',
#  'box_office': '$389,804,217',
#  'country': 'USA',
#  'director': 'James Gunn',
#  'genre': 'Action, Adventure, Comedy, Sci-Fi',
#  'imdbRating': '7.7',
#  'imdbVotes': '431,166',
#  'language': 'English',
#  'main_cast': 'Chris Pratt, Zoe Saldana, Dave Bautista, Vin Diesel',
#  'studio': 'Walt Disney Pictures',
#  'title': 'Guardians of the Galaxy Vol. 2',
#  'writer': 'James Gunn, Dan Abnett (based on the Marvel comics by), Andy '
#            'Lanning (based on the Marvel comics by), Steve Englehart '
#            '(Star-Lord created by), Steve Gan (Star-Lord created by), Jim '
#            'Starlin (Gamora and Drax created by), Stan Lee (Groot created by), '
#            'Larry Lieber (Groot created by), Jack Kirby (Groot created by), '
#            'Bill Mantlo (Rocket Raccoon created by), Keith Giffen (Rocket '
#            'Raccoon created by), Steve Gerber (Howard the Duck created by), '
#            'Val Mayerik (Howard the Duck created by)',
#  'year': '2017'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf30'),
#  'awards': 'Nominated for 3 Oscars. Another 45 wins & 91 nominations.',
#  'box_office': '$381,000,185',
#  'country': 'USA, UK',
#  'director': 'David Yates',
#  'genre': 'Adventure, Drama, Fantasy, Mystery',
#  'imdbRating': '8.1',
#  'imdbVotes': '673,121',
#  'language': 'English',
#  'main_cast': 'Ralph Fiennes, Michael Gambon, Alan Rickman, Daniel Radcliffe',
#  'studio': 'Warner Bros. Pictures',
#  'title': 'Harry Potter and the Deathly Hallows: Part 2',
#  'writer': 'Steve Kloves (screenplay), J.K. Rowling (novel)',
#  'year': '2011'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf31'),
#  'awards': 'Won 1 Oscar. Another 48 wins & 61 nominations.',
#  'box_office': '$380,529,370',
#  'country': 'USA',
#  'director': 'Andrew Stanton, Lee Unkrich(co-director)',
#  'genre': 'Animation, Adventure, Comedy, Family',
#  'imdbRating': '8.1',
#  'imdbVotes': '842,448',
#  'language': 'English',
#  'main_cast': 'Albert Brooks, Ellen DeGeneres, Alexander Gould, Willem Dafoe',
#  'studio': 'Walt Disney Pictures',
#  'title': 'Finding Nemo',
#  'writer': 'Andrew Stanton (original story by), Andrew Stanton (screenplay '
#            'by), Bob Peterson (screenplay by), David Reynolds (screenplay by)',
#  'year': '2003'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf32'),
#  'awards': 'Nominated for 1 Oscar. Another 25 wins & 56 nominations.',
#  'box_office': 'N/A',
#  'country': 'USA, Italy, Switzerland, Thailand, Tunisia',
#  'director': 'George Lucas',
#  'genre': 'Action, Adventure, Fantasy, Sci-Fi',
#  'imdbRating': '7.6',
#  'imdbVotes': '622,401',
#  'language': 'English',
#  'main_cast': 'Ewan McGregor, Natalie Portman, Hayden Christensen, Ian '
#               'McDiarmid',
#  'studio': '20th Century Fox',
#  'title': 'Star Wars: Episode III - Revenge of the Sith',
#  'writer': 'George Lucas',
#  'year': '2005'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf33'),
#  'awards': 'Won 11 Oscars. Another 197 wins & 122 nominations.',
#  'box_office': '$364,000,000',
#  'country': 'New Zealand, USA',
#  'director': 'Peter Jackson',
#  'genre': 'Action, Adventure, Drama, Fantasy',
#  'imdbRating': '8.9',
#  'imdbVotes': '1,451,338',
#  'language': 'English, Quenya, Old English, Sindarin',
#  'main_cast': 'Noel Appleby, Ali Astin, Sean Astin, David Aston',
#  'studio': 'New Line Cinema',
#  'title': 'The Lord of the Rings: The Return of the King',
#  'writer': 'J.R.R. Tolkien (novel), Fran Walsh (screenplay), Philippa Boyens '
#            '(screenplay), Peter Jackson (screenplay)',
#  'year': '2003'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf34'),
#  'awards': 'Won 2 Oscars. Another 24 wins & 25 nominations.',
#  'box_office': '$47,611,331',
#  'country': 'USA',
#  'director': 'Gary Trousdale, Kirk Wise',
#  'genre': 'Animation, Family, Fantasy, Musical, Romance',
#  'imdbRating': '8.0',
#  'imdbVotes': '379,513',
#  'language': 'English, French',
#  'main_cast': 'Robby Benson, Jesse Corti, Rex Everhart, Angela Lansbury',
#  'studio': 'Buena Vista',
#  'title': 'Beauty and the Beast',
#  'writer': 'Linda Woolverton (animation screenplay by), Brenda Chapman (story '
#            'by), Chris Sanders (story by), Burny Mattinson (story by), Kevin '
#            'Harkey (story by), Brian Pimental (story by), Bruce Woodside '
#            '(story by), Joe Ranft (story by), Tom Ellery (story by), Kelly '
#            'Asbury (story by), Robert Lence (story by)',
#  'year': '1991'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf35'),
#  'awards': 'Won 1 Oscar. Another 23 wins & 59 nominations.',
#  'box_office': '$373,377,893',
#  'country': 'USA',
#  'director': 'Sam Raimi',
#  'genre': 'Action, Adventure, Sci-Fi',
#  'imdbRating': '7.3',
#  'imdbVotes': '486,636',
#  'language': 'English, Russian, Chinese',
#  'main_cast': 'Tobey Maguire, Kirsten Dunst, James Franco, Alfred Molina',
#  'studio': 'Sony Pictures',
#  'title': 'Spider-Man 2',
#  'writer': 'Stan Lee (comic book), Steve Ditko (comic book), Alfred Gough '
#            '(screen story), Miles Millar (screen story), Michael Chabon '
#            '(screen story), Alvin Sargent (screenplay)',
#  'year': '2004'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf36'),
#  'awards': 'Nominated for 3 Oscars. Another 28 wins & 21 nominations.',
#  'box_office': '$368,000,000',
#  'country': 'USA',
#  'director': 'Mel Gibson',
#  'genre': 'Drama',
#  'imdbRating': '7.2',
#  'imdbVotes': '197,549',
#  'language': 'Aramaic, Latin, Hebrew',
#  'main_cast': 'Jim Caviezel, Maia Morgenstern, Christo Jivkov, Francesco De '
#               'Vito',
#  'studio': 'Newmarket Film Group',
#  'title': 'The Passion of the Christ',
#  'writer': 'Benedict Fitzgerald (screenplay), Mel Gibson (screenplay)',
#  'year': '2004'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf37'),
#  'awards': '4 wins & 15 nominations.',
#  'box_office': '$368,305,960',
#  'country': 'Japan, USA',
#  'director': 'Chris Renaud, Yarrow Cheney(co-director)',
#  'genre': 'Animation, Adventure, Comedy, Family',
#  'imdbRating': '6.5',
#  'imdbVotes': '155,113',
#  'language': 'English',
#  'main_cast': 'Louis C.K., Eric Stonestreet, Kevin Hart, Jenny Slate',
#  'studio': 'Universal Pictures',
#  'title': 'The Secret Life of Pets',
#  'writer': 'Cinco Paul, Ken Daurio, Brian Lynch',
#  'year': '2016'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf38'),
#  'awards': 'Nominated for 2 Oscars. Another 12 wins & 65 nominations.',
#  'box_office': '$368,049,635',
#  'country': 'USA, France, Japan',
#  'director': 'Pierre Coffin, Chris Renaud',
#  'genre': 'Animation, Adventure, Comedy, Family, Fantasy, Sci-Fi',
#  'imdbRating': '7.4',
#  'imdbVotes': '334,262',
#  'language': 'English, Ukrainian',
#  'main_cast': 'Steve Carell, Kristen Wiig, Benjamin Bratt, Miranda Cosgrove',
#  'studio': 'Universal Pictures',
#  'title': 'Despicable Me 2',
#  'writer': 'Cinco Paul, Ken Daurio',
#  'year': '2013'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf39'),
#  'awards': 'Won 1 Oscar. Another 31 wins & 54 nominations.',
#  'box_office': '$363,995,937',
#  'country': 'UK, USA',
#  'director': 'Jon Favreau',
#  'genre': 'Adventure, Drama, Family, Fantasy',
#  'imdbRating': '7.4',
#  'imdbVotes': '234,639',
#  'language': 'English',
#  'main_cast': 'Neel Sethi, Bill Murray, Ben Kingsley, Idris Elba',
#  'studio': 'Walt Disney Pictures',
#  'title': 'The Jungle Book',
#  'writer': 'Justin Marks (screenplay by), Rudyard Kipling (based on the books '
#            'by)',
#  'year': '2016'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf3a'),
#  'awards': 'Nominated for 2 Golden Globes. Another 27 wins & 73 nominations.',
#  'box_office': '$328,674,489',
#  'country': 'USA',
#  'director': 'Tim Miller',
#  'genre': 'Action, Adventure, Comedy, Sci-Fi',
#  'imdbRating': '8.0',
#  'imdbVotes': '787,883',
#  'language': 'English',
#  'main_cast': 'Ryan Reynolds, Karan Soni, Ed Skrein, Michael Benyaer',
#  'studio': '20th Century Fox',
#  'title': 'Deadpool',
#  'writer': 'Rhett Reese, Paul Wernick',
#  'year': '2016'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf3b'),
#  'awards': 'Won 1 Oscar. Another 93 wins & 112 nominations.',
#  'box_office': '$264,317,903',
#  'country': 'USA',
#  'director': 'Pete Docter, Ronnie Del Carmen(co-director)',
#  'genre': 'Animation, Adventure, Comedy, Drama, Family, Fantasy',
#  'imdbRating': '8.2',
#  'imdbVotes': '515,590',
#  'language': 'English',
#  'main_cast': 'Amy Poehler, Phyllis Smith, Richard Kind, Bill Hader',
#  'studio': 'Disney/Pixar',
#  'title': 'Inside Out',
#  'writer': 'Pete Docter (original story by), Ronnie Del Carmen (original story '
#            'by), Pete Docter (screenplay by), Meg LeFauve (screenplay by), '
#            'Josh Cooley (screenplay by), Michael Arndt (additional story '
#            'material by), Simon Rich (additional story material by), Bill '
#            'Hader (additional dialogue by), Amy Poehler (additional dialogue '
#            'by)',
#  'year': '2015'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf3c'),
#  'awards': 'Nominated for 1 Golden Globe. Another 28 wins & 31 nominations.',
#  'box_office': '$316,986,481',
#  'country': 'Japan, USA, China, United Arab Emirates',
#  'director': 'James Wan',
#  'genre': 'Action, Crime, Thriller',
#  'imdbRating': '7.2',
#  'imdbVotes': '328,928',
#  'language': 'English, Thai, Arabic, Spanish',
#  'main_cast': 'Vin Diesel, Paul Walker, Jason Statham, Michelle Rodriguez',
#  'studio': 'Universal Pictures',
#  'title': 'Furious 7',
#  'writer': 'Chris Morgan, Gary Scott Thompson (characters)',
#  'year': '2015'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf3d'),
#  'awards': 'Nominated for 3 Oscars. Another 10 wins & 39 nominations.',
#  'box_office': '$352,358,779',
#  'country': 'USA',
#  'director': 'Michael Bay',
#  'genre': 'Action, Adventure, Sci-Fi',
#  'imdbRating': '6.3',
#  'imdbVotes': '360,510',
#  'language': 'English',
#  'main_cast': 'Shia LaBeouf, Rosie Huntington-Whiteley, Josh Duhamel, John '
#               'Turturro',
#  'studio': 'Paramount Studios',
#  'title': 'Transformers: Dark of the Moon',
#  'writer': 'Ehren Kruger',
#  'year': '2011'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf3e'),
#  'awards': 'Won 1 Oscar. Another 23 wins & 42 nominations.',
#  'box_office': '$274,377,268',
#  'country': 'USA',
#  'director': 'Clint Eastwood',
#  'genre': 'Action, Biography, Drama, History, Thriller, War',
#  'imdbRating': '7.3',
#  'imdbVotes': '391,759',
#  'language': 'English, Arabic',
#  'main_cast': 'Bradley Cooper, Kyle Gallner, Cole Konis, Ben Reed',
#  'studio': 'Warner Bros.',
#  'title': 'American Sniper',
#  'writer': 'Jason Hall, Chris Kyle (book), Scott McEwen (book), Jim DeFelice '
#            '(book)',
#  'year': '2014'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf3f'),
#  'awards': 'Won 2 Oscars. Another 118 wins & 137 nominations.',
#  'box_office': '$339,700,000',
#  'country': 'New Zealand, USA',
#  'director': 'Peter Jackson',
#  'genre': 'Adventure, Drama, Fantasy',
#  'imdbRating': '8.7',
#  'imdbVotes': '1,310,858',
#  'language': 'English, Sindarin, Old English',
#  'main_cast': 'Bruce Allpress, Sean Astin, John Bach, Sala Baker',
#  'studio': 'New Line Cinema',
#  'title': 'The Lord of the Rings: The Two Towers',
#  'writer': 'J.R.R. Tolkien (novel), Fran Walsh (screenplay), Philippa Boyens '
#            '(screenplay), Stephen Sinclair (screenplay), Peter Jackson '
#            '(screenplay)',
#  'year': '2002'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf40'),
#  'awards': 'Won 1 Oscar. Another 45 wins & 65 nominations.',
#  'box_office': '$341,264,012',
#  'country': 'USA',
#  'director': 'Byron Howard, Rich Moore, Jared Bush(co-director)',
#  'genre': 'Animation, Adventure, Comedy, Crime, Family, Mystery',
#  'imdbRating': '8.0',
#  'imdbVotes': '362,760',
#  'language': 'English',
#  'main_cast': 'Ginnifer Goodwin, Jason Bateman, Idris Elba, Jenny Slate',
#  'studio': 'Walt Disney Animation Studios',
#  'title': 'Zootopia',
#  'writer': 'Byron Howard (story by), Rich Moore (story by), Jared Bush (story '
#            'by), Jim Reardon (story by), Josie Trinidad (story by), Phil '
#            'Johnston (story by), Jennifer Lee (story by), Jared Bush '
#            '(screenplay by), Phil Johnston (screenplay by)',
#  'year': '2016'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf41'),
#  'awards': 'Nominated for 1 Golden Globe. Another 21 wins & 31 nominations.',
#  'box_office': '$295,457,212',
#  'country': 'USA',
#  'director': 'Francis Lawrence',
#  'genre': 'Action, Adventure, Sci-Fi, Thriller',
#  'imdbRating': '6.7',
#  'imdbVotes': '368,111',
#  'language': 'English',
#  'main_cast': 'Jennifer Lawrence, Josh Hutcherson, Liam Hemsworth, Woody '
#               'Harrelson',
#  'studio': 'Lionsgate Films',
#  'title': 'The Hunger Games: Mockingjay - Part 1',
#  'writer': 'Peter Craig (screenplay), Danny Strong (screenplay), Suzanne '
#            'Collins (adaptation), Suzanne Collins (novel)',
#  'year': '2014'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf42'),
#  'awards': 'Nominated for 1 BAFTA Film Award. Another 3 wins & 32 nominations.',
#  'box_office': '$336,530,303',
#  'country': 'USA',
#  'director': 'Sam Raimi',
#  'genre': 'Action, Adventure, Sci-Fi',
#  'imdbRating': '6.2',
#  'imdbVotes': '448,722',
#  'language': 'English, French',
#  'main_cast': 'Tobey Maguire, Kirsten Dunst, James Franco, Thomas Haden Church',
#  'studio': 'Sony Pictures',
#  'title': 'Spider-Man 3',
#  'writer': 'Sam Raimi (screenplay), Ivan Raimi (screenplay), Alvin Sargent '
#            '(screenplay), Sam Raimi (screen story), Ivan Raimi (screen story), '
#            'Stan Lee (Marvel comic book), Steve Ditko (Marvel comic book)',
#  'year': '2007'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf43'),
#  'awards': 'Nominated for 1 BAFTA Film Award. Another 4 wins & 24 nominations.',
#  'box_office': '$277,969,969',
#  'country': 'USA',
#  'director': 'Kyle Balda, Pierre Coffin',
#  'genre': 'Animation, Action, Adventure, Comedy, Family',
#  'imdbRating': '6.4',
#  'imdbVotes': '187,935',
#  'language': 'English, Spanish',
#  'main_cast': 'Sandra Bullock, Jon Hamm, Michael Keaton, Allison Janney',
#  'studio': 'Universal Pictures',
#  'title': 'Minions',
#  'writer': 'Brian Lynch',
#  'year': '2015'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf44'),
#  'awards': '4 wins & 9 nominations.',
#  'box_office': '$334,166,825',
#  'country': 'USA',
#  'director': 'Jon Watts',
#  'genre': 'Action, Adventure, Sci-Fi',
#  'imdbRating': '7.5',
#  'imdbVotes': '383,056',
#  'language': 'English, Spanish',
#  'main_cast': 'Tom Holland, Michael Keaton, Robert Downey Jr., Marisa Tomei',
#  'studio': 'Sony Pictures',
#  'title': 'Spider-Man: Homecoming',
#  'writer': 'Jonathan Goldstein (screenplay by), John Francis Daley (screenplay '
#            'by), Jon Watts (screenplay by), Christopher Ford (screenplay by), '
#            'Chris McKenna (screenplay by), Erik Sommers (screenplay by), '
#            'Jonathan Goldstein (screen story by), John Francis Daley (screen '
#            'story by), Stan Lee (based on the Marvel comic book by), Steve '
#            'Ditko (based on the Marvel comic book by), Joe Simon (Captain '
#            'America created by), Jack Kirby (Captain America created by)',
#  'year': '2017'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf45'),
#  'awards': 'Won 2 Oscars. Another 31 wins & 62 nominations.',
#  'box_office': '$319,323,000',
#  'country': 'USA',
#  'director': 'Tim Burton',
#  'genre': 'Adventure, Family, Fantasy',
#  'imdbRating': '6.5',
#  'imdbVotes': '350,517',
#  'language': 'English',
#  'main_cast': 'Johnny Depp, Mia Wasikowska, Helena Bonham Carter, Anne '
#               'Hathaway',
#  'studio': 'Walt Disney Pictures',
#  'title': 'Alice in Wonderland',
#  'writer': 'Linda Woolverton (screenplay), Lewis Carroll (books)',
#  'year': '2010'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf46'),
#  'awards': 'Nominated for 2 Oscars. Another 52 wins & 99 nominations.',
#  'box_office': '$270,592,504',
#  'country': 'USA',
#  'director': 'James Gunn',
#  'genre': 'Action, Adventure, Comedy, Sci-Fi',
#  'imdbRating': '8.1',
#  'imdbVotes': '895,861',
#  'language': 'English',
#  'main_cast': 'Chris Pratt, Zoe Saldana, Dave Bautista, Vin Diesel',
#  'studio': 'Walt Disney Pictures',
#  'title': 'Guardians of the Galaxy',
#  'writer': 'James Gunn, Nicole Perlman, Dan Abnett (based on the Marvel comics '
#            'by), Andy Lanning (based on the Marvel comics by), Bill Mantlo '
#            '(character created by: Rocket Raccoon), Keith Giffen (character '
#            'created by: Rocket Raccoon), Jim Starlin (characters created by: '
#            'Drax the Destroyer,  Gamora & Thanos), Steve Englehart (character '
#            'created by: Star-Lord), Steve Gan (character created by: '
#            'Star-Lord), Steve Gerber (character created by: Howard the Duck), '
#            'Val Mayerik (character created by: Howard the Duck)',
#  'year': '2014'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf47'),
#  'awards': '14 wins & 30 nominations.',
#  'box_office': '$293,792,936',
#  'country': 'USA',
#  'director': 'Zack Snyder',
#  'genre': 'Action, Adventure, Fantasy, Sci-Fi',
#  'imdbRating': '6.5',
#  'imdbVotes': '558,617',
#  'language': 'English',
#  'main_cast': 'Ben Affleck, Henry Cavill, Amy Adams, Jesse Eisenberg',
#  'studio': 'Warner Bros. Pictures',
#  'title': 'Batman v Superman: Dawn of Justice',
#  'writer': 'Chris Terrio, David S. Goyer, Bob Kane (Batman created by), Bill '
#            'Finger (Batman created by), Jerry Siegel (Superman created by), '
#            'Joe Shuster (Superman created by), William Moulton Marston '
#            '(character created by: Wonder Woman)',
#  'year': '2016'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf48'),
#  'awards': 'Won 6 Oscars. Another 40 wins & 67 nominations.',
#  'box_office': '$330,000,000',
#  'country': 'USA',
#  'director': 'Robert Zemeckis',
#  'genre': 'Drama, Romance',
#  'imdbRating': '8.8',
#  'imdbVotes': '1,550,175',
#  'language': 'English',
#  'main_cast': 'Tom Hanks, Rebecca Williams, Sally Field, Michael Conner '
#               'Humphreys',
#  'studio': 'Paramount Pictures',
#  'title': 'Forrest Gump',
#  'writer': 'Winston Groom (novel), Eric Roth (screenplay)',
#  'year': '1994'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf49'),
#  'awards': '4 wins & 30 nominations.',
#  'box_office': '$326,898,358',
#  'country': 'USA, Canada',
#  'director': 'Andy Muschietti',
#  'genre': 'Horror, Thriller',
#  'imdbRating': '7.4',
#  'imdbVotes': '328,484',
#  'language': 'English',
#  'main_cast': 'Jaeden Lieberher, Jeremy Ray Taylor, Sophia Lillis, Finn '
#               'Wolfhard',
#  'studio': 'Warner Bros. Pictures',
#  'title': 'It',
#  'writer': 'Chase Palmer (screenplay by), Cary Joji Fukunaga (screenplay by), '
#            'Gary Dauberman (screenplay by), Stephen King (based on the novel '
#            'by)',
#  'year': '2017'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf4a'),
#  'awards': 'Won 1 Oscar. Another 16 wins & 37 nominations.',
#  'box_office': '$325,021,779',
#  'country': 'USA',
#  'director': 'David Ayer',
#  'genre': 'Action, Adventure, Fantasy, Sci-Fi',
#  'imdbRating': '6.1',
#  'imdbVotes': '511,443',
#  'language': 'English, Japanese, Spanish',
#  'main_cast': 'Will Smith, Jaime FitzSimons, Ike Barinholtz, Margot Robbie',
#  'studio': 'Warner Bros. Pictures',
#  'title': 'Suicide Squad',
#  'writer': 'David Ayer',
#  'year': '2016'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf4b'),
#  'awards': 'N/A',
#  'box_office': 'N/A',
#  'country': 'USA',
#  'director': 'David Leitch',
#  'genre': 'Action, Adventure, Comedy, Sci-Fi',
#  'imdbRating': '7.8',
#  'imdbVotes': '331,497',
#  'language': 'English, Cantonese, Spanish, Russian',
#  'main_cast': 'Ryan Reynolds, Josh Brolin, Morena Baccarin, Julian Dennison',
#  'studio': '20th Century Fox',
#  'title': 'Deadpool 2',
#  'writer': 'Rhett Reese, Paul Wernick, Ryan Reynolds',
#  'year': '2018'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf4c'),
#  'awards': 'Nominated for 1 BAFTA Film Award. Another 5 wins & 15 nominations.',
#  'box_office': '$320,706,665',
#  'country': 'USA',
#  'director': 'Chris Miller, Raman Hui(co-director)',
#  'genre': 'Animation, Adventure, Comedy, Family, Fantasy',
#  'imdbRating': '6.1',
#  'imdbVotes': '245,876',
#  'language': 'English',
#  'main_cast': 'Mike Myers, Eddie Murphy, Cameron Diaz, Antonio Banderas',
#  'studio': 'Dreamworks',
#  'title': 'Shrek the Third',
#  'writer': 'Jeffrey Price (screenplay by), Peter S. Seaman (screenplay by), '
#            'Chris Miller (screenplay by), Aron Warner (screenplay by), Andrew '
#            'Adamson (story by), William Steig (based upon the book by)',
#  'year': '2007'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf4d'),
#  'awards': 'Nominated for 3 Oscars. Another 20 wins & 41 nominations.',
#  'box_office': '$319,014,499',
#  'country': 'USA',
#  'director': 'Michael Bay',
#  'genre': 'Action, Adventure, Sci-Fi',
#  'imdbRating': '7.1',
#  'imdbVotes': '559,789',
#  'language': 'English, Spanish',
#  'main_cast': 'Shia LaBeouf, Megan Fox, Josh Duhamel, Tyrese Gibson',
#  'studio': 'Dreamworks',
#  'title': 'Transformers',
#  'writer': 'Roberto Orci (screenplay), Alex Kurtzman (screenplay), John Rogers '
#            '(story), Roberto Orci (story), Alex Kurtzman (story)',
#  'year': '2007'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf4e'),
#  'awards': 'Nominated for 2 Oscars. Another 20 wins & 65 nominations.',
#  'box_office': '$318,298,180',
#  'country': 'USA',
#  'director': 'Jon Favreau',
#  'genre': 'Action, Adventure, Sci-Fi',
#  'imdbRating': '7.9',
#  'imdbVotes': '822,686',
#  'language': 'English, Persian, Urdu, Arabic, Hungarian',
#  'main_cast': 'Robert Downey Jr., Terrence Howard, Jeff Bridges, Gwyneth '
#               'Paltrow',
#  'studio': 'Paramount Pictures',
#  'title': 'Iron Man',
#  'writer': 'Mark Fergus (screenplay), Hawk Ostby (screenplay), Art Marcum '
#            '(screenplay), Matt Holloway (screenplay), Stan Lee (characters), '
#            'Don Heck (characters), Larry Lieber (characters), Jack Kirby '
#            '(characters)',
#  'year': '2008'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf4f'),
#  'awards': 'Nominated for 3 Oscars. Another 17 wins & 62 nominations.',
#  'box_office': '$317,557,891',
#  'country': 'UK, USA',
#  'director': 'Chris Columbus',
#  'genre': 'Adventure, Family, Fantasy',
#  'imdbRating': '7.6',
#  'imdbVotes': '553,775',
#  'language': 'English',
#  'main_cast': 'Richard Harris, Maggie Smith, Robbie Coltrane, Saunders '
#               'Triplets',
#  'studio': 'Warner Bros. Pictures',
#  'title': "Harry Potter and the Sorcerer's Stone",
#  'writer': 'J.K. Rowling (novel), Steve Kloves (screenplay)',
#  'year': '2001'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf50'),
#  'awards': 'Nominated for 1 BAFTA Film Award. Another 10 wins & 35 '
#            'nominations.',
#  'box_office': '$316,957,122',
#  'country': 'USA',
#  'director': 'Steven Spielberg',
#  'genre': 'Action, Adventure, Fantasy',
#  'imdbRating': '6.2',
#  'imdbVotes': '383,032',
#  'language': 'English, German, Russian',
#  'main_cast': 'Harrison Ford, Cate Blanchett, Karen Allen, Shia LaBeouf',
#  'studio': 'Paramount Pictures',
#  'title': 'Indiana Jones and the Kingdom of the Crystal Skull',
#  'writer': 'David Koepp (screenplay), George Lucas (story), Jeff Nathanson '
#            '(story), George Lucas (characters), Philip Kaufman (characters)',
#  'year': '2008'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf51'),
#  'awards': 'Won 4 Oscars. Another 113 wins & 123 nominations.',
#  'box_office': '$314,000,000',
#  'country': 'New Zealand, USA',
#  'director': 'Peter Jackson',
#  'genre': 'Adventure, Drama, Fantasy',
#  'imdbRating': '8.8',
#  'imdbVotes': '1,466,530',
#  'language': 'English, Sindarin',
#  'main_cast': 'Alan Howard, Noel Appleby, Sean Astin, Sala Baker',
#  'studio': 'New Line Cinema',
#  'title': 'The Lord of the Rings: The Fellowship of the Ring',
#  'writer': 'J.R.R. Tolkien (novel), Fran Walsh (screenplay), Philippa Boyens '
#            '(screenplay), Peter Jackson (screenplay)',
#  'year': '2001'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf52'),
#  'awards': '5 wins & 30 nominations.',
#  'box_office': '$314,971,245',
#  'country': 'USA, Australia',
#  'director': 'Taika Waititi',
#  'genre': 'Action, Adventure, Comedy, Fantasy, Sci-Fi',
#  'imdbRating': '7.9',
#  'imdbVotes': '419,376',
#  'language': 'English',
#  'main_cast': 'Chris Hemsworth, Tom Hiddleston, Cate Blanchett, Idris Elba',
#  'studio': 'Walt Disney Pictures',
#  'title': 'Thor: Ragnarok',
#  'writer': 'Eric Pearson, Craig Kyle, Christopher L. Yost, Stan Lee (based on '
#            'the Marvel comics by), Larry Lieber (based on the Marvel comics '
#            'by), Jack Kirby (based on the Marvel comics by)',
#  'year': '2017'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf53'),
#  'awards': 'Nominated for 1 Oscar. Another 7 wins & 42 nominations.',
#  'box_office': '$312,057,433',
#  'country': 'USA',
#  'director': 'Jon Favreau',
#  'genre': 'Action, Sci-Fi',
#  'imdbRating': '7.0',
#  'imdbVotes': '624,288',
#  'language': 'English, French, Russian',
#  'main_cast': 'Robert Downey Jr., Gwyneth Paltrow, Don Cheadle, Scarlett '
#               'Johansson',
#  'studio': 'Paramount Studios',
#  'title': 'Iron Man 2',
#  'writer': 'Justin Theroux (screenplay), Stan Lee (Marvel comic book), Don '
#            'Heck (Marvel comic book), Larry Lieber (Marvel comic book), Jack '
#            'Kirby (Marvel comic book)',
#  'year': '2010'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf54'),
#  'awards': 'Nominated for 1 Oscar. Another 16 wins & 58 nominations.',
#  'box_office': '$307,900,000',
#  'country': 'USA',
#  'director': 'George Lucas',
#  'genre': 'Action, Adventure, Fantasy, Sci-Fi',
#  'imdbRating': '6.6',
#  'imdbVotes': '559,024',
#  'language': 'English',
#  'main_cast': 'Ewan McGregor, Natalie Portman, Hayden Christensen, Christopher '
#               'Lee',
#  'studio': '20th Century Fox',
#  'title': 'Star Wars: Episode II - Attack of the Clones',
#  'writer': 'George Lucas (screenplay by), Jonathan Hales (screenplay by), '
#            'George Lucas (story by)',
#  'year': '2002'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf55'),
#  'awards': 'Nominated for 2 Oscars. Another 20 wins & 44 nominations.',
# ...
#  'language': 'English',
#  'main_cast': 'Will Smith, Bill Pullman, Jeff Goldblum, Mary McDonnell',
#  'studio': '20th Century Fox',
#  'title': 'Independence Day',
#  'writer': 'Dean Devlin, Roland Emmerich',
#  'year': '1996'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf58'),
#  'awards': 'Nominated for 5 Oscars. Another 36 wins & 96 nominations.',
#  'box_office': '$305,343,252',
#  'country': 'USA',
#  'director': 'Gore Verbinski',
#  'genre': 'Action, Adventure, Fantasy',
#  'imdbRating': '8.0',
#  'imdbVotes': '944,014',
#  'language': 'English',
#  'main_cast': 'Johnny Depp, Geoffrey Rush, Orlando Bloom, Keira Knightley',
#  'studio': 'Buena Vista Pictures',
#  'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#  'writer': 'Ted Elliott (screen story), Terry Rossio (screen story), Stuart '
#            'Beattie (screen story), Jay Wolpert (screen story), Ted Elliott '
#            '(screenplay), Terry Rossio (screenplay)',
#  'year': '2003'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf59'),
#  'awards': 'Won 2 Oscars. Another 65 wins & 119 nominations.',
#  'box_office': '$299,300,000',
#  'country': 'UK, USA',
#  'director': 'Sam Mendes',
#  'genre': 'Action, Adventure, Thriller',
#  'imdbRating': '7.8',
#  'imdbVotes': '582,802',
#  'language': 'English, Turkish',
#  'main_cast': 'Daniel Craig, Judi Dench, Javier Bardem, Ralph Fiennes',
#  'studio': 'MGM',
#  'title': 'Skyfall',
#  'writer': 'Neal Purvis, Robert Wade, John Logan, Ian Fleming (characters)',
#  'year': '2012'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf5a'),
#  'awards': 'Nominated for 3 Oscars. Another 10 wins & 72 nominations.',
#  'box_office': '$303,001,229',
#  'country': 'USA, New Zealand',
#  'director': 'Peter Jackson',
#  'genre': 'Adventure, Family, Fantasy',
#  'imdbRating': '7.9',
#  'imdbVotes': '709,013',
#  'language': 'English',
#  'main_cast': 'Ian McKellen, Martin Freeman, Richard Armitage, Ken Stott',
#  'studio': 'Warner Bros.',
#  'title': 'The Hobbit: An Unexpected Journey',
#  'writer': 'Fran Walsh (screenplay), Philippa Boyens (screenplay), Peter '
#            'Jackson (screenplay), Guillermo del Toro (screenplay), J.R.R. '
#            'Tolkien (novel)',
#  'year': '2012'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf5b'),
#  'awards': 'Nominated for 1 Oscar. Another 8 wins & 35 nominations.',
#  'box_office': '$301,920,409',
#  'country': 'UK, USA',
#  'director': 'David Yates',
#  'genre': 'Adventure, Family, Fantasy, Mystery',
#  'imdbRating': '7.6',
#  'imdbVotes': '402,648',
#  'language': 'English',
#  'main_cast': 'Daniel Radcliffe, Michael Gambon, Dave Legeno, Elarica Johnson',
#  'studio': 'Warner Bros. Pictures',
#  'title': 'Harry Potter and the Half-Blood Prince',
#  'writer': 'Steve Kloves (screenplay), J.K. Rowling (novel)',
#  'year': '2009'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf5c'),
#  'awards': '22 wins & 34 nominations.',
#  'box_office': '$300,523,113',
#  'country': 'USA',
#  'director': 'David Slade',
#  'genre': 'Adventure, Drama, Fantasy, Romance',
#  'imdbRating': '5.0',
#  'imdbVotes': '207,159',
#  'language': 'English',
#  'main_cast': 'Xavier Samuel, Kristen Stewart, Robert Pattinson, Billy Burke',
#  'studio': 'Summit Entertainment',
#  'title': 'The Twilight Saga: Eclipse',
#  'writer': 'Melissa Rosenberg (screenplay), Stephenie Meyer (novel)',
#  'year': '2010'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf5d'),
#  'awards': '20 wins & 24 nominations.',
#  'box_office': '$296,593,070',
#  'country': 'USA',
#  'director': 'Chris Weitz',
#  'genre': 'Adventure, Drama, Fantasy, Romance',
#  'imdbRating': '4.7',
#  'imdbVotes': '243,897',
#  'language': 'English, Italian',
#  'main_cast': 'Kristen Stewart, Christina Jastrzembska, Robert Pattinson, '
#               'Billy Burke',
#  'studio': 'Summit Entertainment',
#  'title': 'The Twilight Saga: New Moon',
#  'writer': 'Melissa Rosenberg (screenplay), Stephenie Meyer (novel)',
#  'year': '2009'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf5e'),
#  'awards': 'Nominated for 2 Oscars. Another 15 wins & 53 nominations.',
#  'box_office': '$294,980,434',
#  'country': 'UK, USA',
#  'director': 'David Yates',
#  'genre': 'Adventure, Fantasy, Mystery',
#  'imdbRating': '7.7',
#  'imdbVotes': '407,896',
#  'language': 'English',
#  'main_cast': 'Bill Nighy, Emma Watson, Richard Griffiths, Harry Melling',
#  'studio': 'Warner Bros. Pictures',
#  'title': 'Harry Potter and the Deathly Hallows: Part 1',
#  'writer': 'Steve Kloves (screenplay), J.K. Rowling (novel)',
#  'year': '2010'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf5f'),
#  'awards': 'Nominated for 6 Oscars. Another 32 wins & 48 nominations.',
#  'box_office': 'N/A',
#  'country': 'USA',
#  'director': 'M. Night Shyamalan',
#  'genre': 'Drama, Mystery, Thriller',
#  'imdbRating': '8.1',
#  'imdbVotes': '826,417',
#  'language': 'English, Latin, Spanish',
#  'main_cast': 'Bruce Willis, Haley Joel Osment, Toni Collette, Olivia Williams',
#  'studio': 'Hollywood/Buena Vista',
#  'title': 'The Sixth Sense',
#  'writer': 'M. Night Shyamalan',
#  'year': '1999'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf60'),
#  'awards': 'Won 2 Oscars. Another 74 wins & 81 nominations.',
#  'box_office': '$292,979,556',
#  'country': 'USA',
#  'director': 'Pete Docter, Bob Peterson(co-director)',
#  'genre': 'Animation, Adventure, Comedy, Family',
#  'imdbRating': '8.3',
#  'imdbVotes': '821,327',
#  'language': 'English',
#  'main_cast': 'Edward Asner, Christopher Plummer, Jordan Nagai, Bob Peterson',
#  'studio': 'Walt Disney Pictures',
#  'title': 'Up',
#  'writer': 'Pete Docter (story by), Bob Peterson (story by), Tom McCarthy '
#            '(story by), Bob Peterson (screenplay by), Pete Docter (screenplay '
#            'by)',
#  'year': '2009'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf61'),
#  'awards': 'N/A',
#  'box_office': 'N/A',
#  'country': 'Australia, USA',
#  'director': 'James Wan',
#  'genre': 'Action, Adventure, Fantasy, Sci-Fi',
#  'imdbRating': '7.9',
#  'imdbVotes': '24,893',
#  'language': 'English',
#  'main_cast': 'Jason Momoa, Amber Heard, Willem Dafoe, Patrick Wilson',
#  'studio': 'Warner Bros. Pictures',
#  'title': 'Aquaman',
#  'writer': 'David Leslie Johnson-McGoldrick (screenplay by), Will Beall '
#            '(screenplay by), Geoff Johns (story by), James Wan (story by), '
#            'Will Beall (story by), Mort Weisinger (Aquaman created by), Paul '
#            'Norris (Aquaman created by)',
#  'year': '2018'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf62'),
#  'awards': 'Won 4 Oscars. Another 152 wins & 204 nominations.',
#  'box_office': '$292,568,851',
#  'country': 'USA, UK',
#  'director': 'Christopher Nolan',
#  'genre': 'Action, Adventure, Sci-Fi, Thriller',
#  'imdbRating': '8.8',
#  'imdbVotes': '1,779,523',
#  'language': 'English, Japanese, French',
#  'main_cast': 'Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen Page, Tom Hardy',
#  'studio': 'Warner Bros. Pictures',
#  'title': 'Inception',
#  'writer': 'Christopher Nolan',
#  'year': '2010'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf63'),
#  'awards': '21 wins & 14 nominations.',
#  'box_office': '$292,298,923',
#  'country': 'USA',
#  'director': 'Bill Condon',
#  'genre': 'Adventure, Drama, Fantasy, Romance',
#  'imdbRating': '5.5',
#  'imdbVotes': '210,369',
#  'language': 'English',
#  'main_cast': 'Kristen Stewart, Robert Pattinson, Taylor Lautner, Peter '
#               'Facinelli',
#  'studio': 'Lionsgate/Summit Entertainment',
#  'title': 'The Twilight Saga: Breaking Dawn - Part 2',
#  'writer': 'Melissa Rosenberg (screenplay), Stephenie Meyer (novel)',
#  'year': '2012'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf64'),
#  'awards': 'Nominated for 2 BAFTA Film Awards. Another 14 wins & 40 '
#            'nominations.',
#  'box_office': '$291,980,108',
#  'country': 'UK, USA',
#  'director': 'David Yates',
#  'genre': 'Adventure, Family, Fantasy, Mystery',
#  'imdbRating': '7.5',
#  'imdbVotes': '436,741',
#  'language': 'English',
#  'main_cast': 'Daniel Radcliffe, Harry Melling, Jason Boyd, Richard Macklin',
#  'studio': 'Warner Bros. Pictures',
#  'title': 'Harry Potter and the Order of the Phoenix',
#  'writer': 'Michael Goldenberg (screenplay), J.K. Rowling (novel)',
#  'year': '2007'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf65'),
#  'awards': 'Won 1 Oscar. Another 14 wins & 46 nominations.',
#  'box_office': '$291,685,219',
#  'country': 'USA, UK',
#  'director': 'Andrew Adamson',
#  'genre': 'Adventure, Family, Fantasy',
#  'imdbRating': '6.9',
#  'imdbVotes': '331,570',
#  'language': 'English, German, Brazilian Sign Language',
#  'main_cast': 'Georgie Henley, Skandar Keynes, William Moseley, Anna '
#               'Popplewell',
#  'studio': 'Buena Vista',
#  'title': 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#  'writer': 'Ann Peacock (screenplay), Andrew Adamson (screenplay), Christopher '
#            'Markus (screenplay), Stephen McFeely (screenplay), C.S. Lewis '
#            '(book)',
#  'year': '2005'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf66'),
#  'awards': '7 wins & 46 nominations.',
#  'box_office': '$291,021,565',
#  'country': 'USA, UK',
#  'director': 'Zack Snyder',
#  'genre': 'Action, Adventure, Fantasy, Sci-Fi',
#  'imdbRating': '7.1',
#  'imdbVotes': '629,830',
#  'language': 'English',
#  'main_cast': 'Henry Cavill, Amy Adams, Michael Shannon, Diane Lane',
#  'studio': 'Warner Bros. Pictures',
#  'title': 'Man of Steel',
#  'writer': 'David S. Goyer (screenplay), David S. Goyer (story), Christopher '
#            'Nolan (story), Jerry Siegel (Superman created by), Joe Shuster '
#            '(Superman created by)',
#  'year': '2013'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf67'),
#  'awards': 'Won 1 Oscar. Another 21 wins & 19 nominations.',
#  'box_office': '$4,548,170',
#  'country': 'USA',
#  'director': 'Irvin Kershner',
#  'genre': 'Action, Adventure, Fantasy, Sci-Fi',
#  'imdbRating': '8.8',
#  'imdbVotes': '1,021,079',
#  'language': 'English',
#  'main_cast': 'Mark Hamill, Harrison Ford, Carrie Fisher, Billy Dee Williams',
#  'studio': 'Twentieth Century Fox',
#  'title': 'Star Wars: Episode V - The Empire Strikes Back',
#  'writer': 'Leigh Brackett (screenplay by), Lawrence Kasdan (screenplay by), '
#            'George Lucas (story by)',
#  'year': '1980'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf68'),
#  'awards': 'Nominated for 1 Oscar. Another 13 wins & 42 nominations.',
#  'box_office': '$289,994,397',
#  'country': 'UK, USA',
#  'director': 'Mike Newell',
#  'genre': 'Adventure, Family, Fantasy, Mystery',
#  'imdbRating': '7.7',
#  'imdbVotes': '474,003',
#  'language': 'English, French',
#  'main_cast': 'Eric Sykes, Timothy Spall, David Tennant, Daniel Radcliffe',
#  'studio': 'Warner Bros. Pictures',
#  'title': 'Harry Potter and the Goblet of Fire',
#  'writer': 'Steve Kloves (screenplay), J.K. Rowling (novel)',
#  'year': '2005'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf69'),
#  'awards': 'Won 1 Oscar. Another 13 wins & 38 nominations.',
#  'box_office': '$34,034,168',
#  'country': 'USA',
#  'director': 'Pete Docter, David Silverman(co-director), Lee '
#              'Unkrich(co-director)',
#  'genre': 'Animation, Adventure, Comedy, Family, Fantasy',
#  'imdbRating': '8.1',
#  'imdbVotes': '718,325',
#  'language': 'English',
#  'main_cast': 'John Goodman, Billy Crystal, Mary Gibbs, Steve Buscemi',
#  'studio': 'Buena Vista Distribution Compa',
#  'title': 'Monsters, Inc.',
#  'writer': 'Pete Docter (original story by), Jill Culton (original story by), '
#            'Jeff Pidgeon (original story by), Ralph Eggleston (original story '
#            'by), Andrew Stanton (screenplay by), Daniel Gerson (screenplay '
#            'by), Bob Peterson (additional story material), David Silverman '
#            '(additional story material), Joe Ranft (additional story '
#            'material), Robert L. Baird (additional screenplay material), Rhett '
#            'Reese (additional screenplay material), Jonathan Roberts '
#            '(additional screenplay material)',
#  'year': '2001'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf6a'),
#  'awards': 'Nominated for 2 Oscars. Another 10 wins & 4 nominations.',
#  'box_office': 'N/A',
#  'country': 'USA',
#  'director': 'Chris Columbus',
#  'genre': 'Comedy, Family',
#  'imdbRating': '7.5',
#  'imdbVotes': '393,574',
#  'language': 'English',
#  'main_cast': 'Macaulay Culkin, Joe Pesci, Daniel Stern, John Heard',
#  'studio': 'Twentieth Century Fox',
#  'title': 'Home Alone',
#  'writer': 'John Hughes',
#  'year': '1990'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf6b'),
#  'awards': '17 wins & 34 nominations.',
#  'box_office': '$254,641,329',
#  'country': 'Germany, USA',
#  'director': 'Francis Lawrence',
#  'genre': 'Action, Adventure, Sci-Fi, Thriller',
#  'imdbRating': '6.6',
#  'imdbVotes': '241,696',
#  'language': 'English',
#  'main_cast': 'Jennifer Lawrence, Josh Hutcherson, Liam Hemsworth, Woody '
#               'Harrelson',
#  'studio': 'Lionsgate Films',
#  'title': 'The Hunger Games: Mockingjay - Part 2',
#  'writer': 'Peter Craig (screenplay), Danny Strong (screenplay), Suzanne '
#            'Collins (adaptation), Suzanne Collins (novel)',
#  'year': '2015'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf6c'),
#  'awards': '8 wins & 31 nominations.',
#  'box_office': '$281,500,000',
#  'country': 'USA',
#  'director': 'Lana Wachowski, Lilly Wachowski',
#  'genre': 'Action, Sci-Fi',
#  'imdbRating': '7.2',
#  'imdbVotes': '469,313',
#  'language': 'English, French',
#  'main_cast': 'Ray Anthony, Christine Anu, Andy Arness, Alima Ashton-Sheibu',
#  'studio': 'Warner Bros. Pictures',
#  'title': 'The Matrix Reloaded',
#  'writer': 'Lilly Wachowski, Lana Wachowski, Lilly Wachowski (characters), '
#            'Lana Wachowski (characters)',
#  'year': '2003'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf6d'),
#  'awards': '11 wins & 22 nominations.',
#  'box_office': '$281,267,663',
#  'country': 'USA',
#  'director': 'Bill Condon',
#  'genre': 'Adventure, Drama, Fantasy, Romance',
#  'imdbRating': '4.9',
#  'imdbVotes': '204,370',
#  'language': 'English, Portuguese',
#  'main_cast': 'Taylor Lautner, Gil Birmingham, Billy Burke, Sarah Clarke',
#  'studio': 'Summit Entertainment',
#  'title': 'The Twilight Saga: Breaking Dawn - Part 1',
#  'writer': 'Melissa Rosenberg (screenplay), Stephenie Meyer (novel)',
#  'year': '2011'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf6e'),
#  'awards': '2 wins & 7 nominations.',
#  'box_office': '$279,167,575',
#  'country': 'USA',
#  'director': 'Jay Roach',
#  'genre': 'Comedy, Romance',
#  'imdbRating': '6.3',
#  'imdbVotes': '233,894',
#  'language': 'English, Spanish, Hebrew',
#  'main_cast': 'Robert De Niro, Ben Stiller, Dustin Hoffman, Barbra Streisand',
#  'studio': 'Universal Pictures',
#  'title': 'Meet the Fockers',
#  'writer': 'Greg Glienna (characters), Mary Ruth Clarke (characters), Jim '
#            'Herzfeld (story), Marc Hyman (story), Jim Herzfeld (screenplay), '
#            'John Hamburg (screenplay)',
#  'year': '2004'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf6f'),
#  'awards': 'Won 1 Golden Globe. Another 12 wins & 25 nominations.',
#  'box_office': '$277,313,371',
#  'country': 'USA, Germany',
#  'director': 'Todd Phillips',
#  'genre': 'Comedy',
#  'imdbRating': '7.7',
#  'imdbVotes': '656,156',
#  'language': 'English',
#  'main_cast': 'Bradley Cooper, Ed Helms, Zach Galifianakis, Justin Bartha',
#  'studio': 'Warner Bros. Pictures',
#  'title': 'The Hangover',
#  'writer': 'Jon Lucas, Scott Moore',
#  'year': '2009'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf70'),
#  'awards': 'Won 7 Oscars. Another 232 wins & 175 nominations.',
#  'box_office': '$274,084,951',
#  'country': 'UK, USA',
#  'director': 'Alfonso Cuarón',
#  'genre': 'Drama, Sci-Fi, Thriller',
#  'imdbRating': '7.7',
#  'imdbVotes': '685,873',
#  'language': 'English, Greenlandic',
#  'main_cast': 'Sandra Bullock, George Clooney, Ed Harris, Orto Ignatiussen',
#  'studio': 'Warner Bros. Pictures',
#  'title': 'Gravity',
#  'writer': 'Alfonso Cuarón, Jonás Cuarón',
#  'year': '2013'}
# {'_id': ObjectId('5c42a38eb520d90c43bccf71'),
#  'awards': 'Nominated for 2 Golden Globes. Another 2 wins & 21 nominations.',
#  'box_office': '$270,322,940',
#  'country': 'Japan, USA',
#  'director': 'Garth Jennings, Christophe Lourdelet(co-director)',
#  'genre': 'Animation, Comedy, Family, Musical',
#  'imdbRating': '7.1',
#  'imdbVotes': '109,383',
#  'language': 'English, Japanese, Ukrainian',
#  'main_cast': 'Matthew McConaughey, Reese Witherspoon, Seth MacFarlane, '
#               'Scarlett Johansson',
#  'studio': 'Illumination Entertainment',
#  'title': 'Sing',
#  'writer': 'Garth Jennings',
#  'year': '2016'}
