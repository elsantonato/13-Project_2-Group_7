# %% [markdown]
# <h2>Scraping Metacritic Scores

# %%
# Import Dependencies
import requests
from pprint import pprint
import pandas as pd
from bs4 import BeautifulSoup as bs
from decimal import Decimal
import re

# %%
# Try Metacritic Scrape for Top 100 Ranked Movies
url = 'https://www.metacritic.com/browse/movies/score/metascore/all/filtered?sort=desc'
print(requests.get(url))
# Out:
# <Response [403]>

# %%
# Add headers to bypass 403 Forbidden Access
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/12.0 Safari/605.1.15'}
response = requests.get(url, timeout=30, headers=headers)
print(response)
# Out:
# <Response [200]>

# %%
# Parse the HTML text using Beautiful Soup
soup = bs(response.text, 'html.parser')

# Find and append the metacritic score, rank, title, and short summary of each movie
top_100_metacritic_dicts = []
for td in soup.find_all('td', class_ = 'clamp-summary-wrap'):
    score = td.find('div', class_ = 'clamp-score-wrap').text.strip()
    rank = td.find('span', class_ = 'title numbered').text.strip()[:-1]
    title = td.find('a', class_ = 'title').text.strip()
    summary = td.find('div', class_ = 'summary').text.strip()
    top_100_metacritic_dicts.append({'score': score,
                                    'rank': rank,
                                    'title': title,
                                    'summary': summary})

print(len(top_100_metacritic_dicts))
# Out:
# 100

# %% [markdown]
# <h2>Scraping Base Data (Top 100 Grossing Movies)

# %%
# Scrape the base data from the-numbers.com (for Top 100 Grossing Movies)
response = requests.get("https://www.the-numbers.com/box-office-records/domestic/all-movies/cumulative/all-time")
base_df_1 = pd.read_html(response.text)[0]
base_df_2 = pd.read_html(response.text)[1]
base_df = base_df_1.append(base_df_2).reset_index(drop=True)

# Fix cut off titles
base_df = base_df.replace(base_df.iloc[74]['Movie'], 'Pirates of the Caribbean: The Curse of the Black Pearl')
base_df = base_df.replace(base_df.iloc[87]['Movie'], 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe')

base_df = base_df.rename(columns = {"Movie":"title"})

# Make a copy of dataframe
base_df2 = base_df.copy()

# Loop through copy of dataframe and convert money text to decimal formatting
for index, row in base_df2.iterrows():
    # Convert to decimal
    money = re.match(r'\$\d+,\d+,\d+', row['DomesticBox Office']).group()
    base_df2 = base_df2.replace(row['DomesticBox Office'], Decimal(re.sub(r'[^\d.]', '', money)))
    money = re.match(r'\$\d+,\d+,\d+', row['InternationalBox Office']).group()
    base_df2 = base_df2.replace(row['InternationalBox Office'], Decimal(re.sub(r'[^\d.]', '', money)))
    money = re.match(r'\$\d+,\d+,\d+', row['WorldwideBox Office']).group()
    base_df2 = base_df2.replace(row['WorldwideBox Office'], Decimal(re.sub(r'[^\d.]', '', money)))

base_df2.head()
# Out:
#    Rank  Released                                 title DomesticBox Office  \
# 0     1      2015  Star Wars Ep. VII: The Force Awakens          936662225
# 1     2      2009                                Avatar          760507625
# 2     3      2018                         Black Panther          700059566
# 3     4      2018                Avengers: Infinity War          678815482
# 4     5      1997                               Titanic          659363944
#
#   InternationalBox Office WorldwideBox Office
# 0                 1116648             2053311
# 1                 2015837             2776345
# 2               648300000             1348359
# 3                 1369988             2048803
# 4                 1548844             2208208

# %% [markdown]
# <h2>Scraping Base Data Movies (Top 100 Grossing Movies) from Metacritic

# %%
# Prepare Movie Title URLs for Metacritic calls
urls = []
found_first = False
for title in base_df.title:

    url_title = title.replace(' ', '-').replace(',', '').lower().replace('â', '')

    if ',' in url_title:
        url_title = url_title
    if 'â' in url_title:
        url_title = url_title

    # Replace ep. viii: with viii-- and all other cases found in top100 grossing movie titles
    if 'ep.-iv:' in url_title:
        url_title = url_title.replace('ep.-iv:', 'episode-iv--')
    elif 'ep.-iii:' in url_title:
        url_title = url_title.replace('ep.-iii:', 'episode-iii--')
    elif 'ep.-viii:' in url_title:
        url_title = url_title.replace('ep.-viii:', 'episode-viii--')
    elif 'ep.-vii:' in url_title:
        url_title = url_title.replace('ep.-vii:', 'episode-vii--')
    elif 'ep.-vi:' in url_title:
        url_title = url_title.replace('ep.-vi:', 'episode-vi--')
    elif 'ep.-v:' in url_title:
        url_title = url_title.replace('ep.-v:', 'episode-v--')
    elif 'ep.-ii:' in url_title:
        url_title = url_title.replace('ep.-ii:', 'episode-ii--')
    elif 'ep.-i:' in url_title:
        url_title = url_title.replace('ep.-i:', 'episode-i--')
    elif 'part-ii' in url_title in url_title:
        url_title = url_title.replace('part-ii', 'part-2')
    elif 'part-i' in url_title and not 'harry' in url_title:
        url_title = url_title.replace('part-i', 'part-1')
    
    # Now replace ':' and '.' with '' since we don't need it for matching anymore
    if ':' in url_title:
        url_title = url_title.replace(':', '')
    if '.' in url_title:
        url_title = url_title.replace('.', '')

    # Special cases of URLs:
    if title == 'The Twilight Saga: Breaking Dawn, Part 2':
        url_title = 'the-twilight-saga-breaking-dawn---part-2'
    if title == 'The Twilight Saga: Breaking Dawn, Part 1':
        url_title = 'the-twilight-saga-breaking-dawn---part-1'
    # The Avengers 2012
    if 'The Avengers' in title:
        url_title = 'the-avengers-2012'
    # Beauty and the Beast 2017 and 1991
    if 'Beauty and the Beast' in title:
        if found_first != True:
            url_title = 'beauty-and-the-beast-2017'
            found_first = True
        else:
            url_title = 'beauty-and-the-beast-1991'
    # Frozen 2013
    if 'Frozen' in title:
        url_title = 'frozen-2013'
    # The Jungle Book 2016
    if 'The Jungle Book' in title:
        url_title = 'the-jungle-book-2016'
    # Inside Out 2015
    if 'Inside Out' in title:
        url_title = 'inside-out-2015'
    
    urls.append({'title': title, 'url': 'https://www.metacritic.com/movie/' + url_title})
    
len(urls)
# Out:
# 100

# %%
# Scraping Metacritic for each of the top 100 grossing movies
top_100_grossing_metacritic_dicts = []

for url in urls:

    # Parse the HTML text using Beautiful Soup
    soup = bs(requests.get(url['url'], timeout=30, headers=headers).text, 'html.parser')
    
    # Find and append the release date, metacritic critic(meta) and user scores, production studio, 
    # diretor, main cast, genres, and parental rating, and runtime of each movie
    
    # Release Date
    try:
        for span in soup.find_all('span', class_ = 'release_date'):
            release_date = span.find_all('span')[1].text.strip()
    except:
        release_date = ''
    # Scores
    try:
        #critic_score = soup.find('div', class_ = 'primary_baby_item oswald').text.strip().split('\n')[0]
        #critic_score = soup.find('div', class_ = 'score fl').text.strip()
        scores = []
        for a in soup.find_all('a', class_ = 'metascore_anchor'):
            scores.append(a.text.strip())
        critic_score = scores[0]
        user_score = scores[1]
    except:
        critic_score = ''
        user_score = ''
        print(url['url'])
        
    # Production Studio
    try:
        studio = soup.find('span', class_ = 'distributor').text.strip()[:-2]
    except:
        studio = ''
        
    # Director
    try:
        director = soup.find('div', class_ = 'director').text.strip().split('\n')[1]
    except:
        director = ''
        
    # Main Cast
    try:
        main_cast = soup.find('div', class_ = 'summary_cast details_section').text.strip().split('\n')[2].replace('  ', '').split(',')
    except:
        main_cast = ''
    
    # Genres
    try:
        genres = soup.find('div', class_ = 'genres').text.strip()[11:].replace(' ', '').split(',')
    except:
        genres = ''
    
    # Parental Rating
    try:
        parental_rating = soup.find('div', class_ = 'rating').text.strip().split('\n')[3].replace('  ', '')
    except:
        parental_rating = ''

    # Runtime
    try:
        runtime = soup.find('div', class_ = 'runtime').text.strip()[9:]
    except:
        runtime = ''
    
    # Append data as a dictionary to list of dictionaries
    top_100_grossing_metacritic_dicts.append({'title': url['title'],
                                              'release_date': release_date,
                                              'critic_score': critic_score,
                                              'user_score': user_score,
                                              'studio': studio,
                                              'director': director,
                                              'main_cast': main_cast,
                                              'genres': genres,
                                              'parental_rating': parental_rating,
                                              'runtime': runtime
                                             })

pprint(top_100_grossing_metacritic_dicts)
# Out:
# [{'critic_score': '81',
#   'director': 'J.J. Abrams',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Fantasy'],
#   'main_cast': ['Adam Driver',
#                 ' Carrie Fisher',
#                 ' Daisy Ridley',
#                 ' Domhnall Gleeson',
#                 ' Harrison Ford',
#                 ' John Boyega',
#                 ' Mark Hamill',
#                 ' Oscar Isaac'],
#   'parental_rating': 'PG-13',
#   'release_date': 'December 18, 2015',
#   'runtime': '135 min',
#   'studio': 'Walt Disney Studios Motion Pictures',
#   'title': 'Star Wars Ep. VII: The Force Awakens',
#   'user_score': '6.8'},
#  {'critic_score': '83',
#   'director': 'James Cameron',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Fantasy'],
#   'main_cast': ['Michelle Rodriguez', ' Sam Worthington', ' Sigourney Weaver'],
#   'parental_rating': 'PG-13',
#   'release_date': 'December 18, 2009',
#   'runtime': '162 min',
#   'studio': 'Twentieth Century Fox Film Corporation',
#   'title': 'Avatar',
#   'user_score': '7.5'},
#  {'critic_score': '88',
#   'director': 'Ryan Coogler',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Drama'],
#   'main_cast': ['Andy Serkis',
#                 ' Angela Bassett',
#                 ' Chadwick Boseman',
#                 ' Danai Gurira',
#                 ' Daniel Kaluuya',
#                 ' Forest Whitaker',
#                 ' Letitia Wright',
#                 " Lupita Nyong'o",
#                 ' Martin Freeman',
#                 ' Michael B. Jordan',
#                 ' Stan Lee',
#                 ' Sterling K. Brown',
#                 ' Winston Duke'],
#   'parental_rating': 'PG-13',
#   'release_date': 'February 16, 2018',
#   'runtime': '134 min',
#   'studio': 'Walt Disney Studios Motion Pictures',
#   'title': 'Black Panther',
#   'user_score': '6.6'},
#  {'critic_score': '68',
#   'director': 'Anthony Russo and Joe Russo',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Fantasy'],
#   'main_cast': ['Angela Bassett',
#                 ' Benedict Cumberbatch',
#                 ' Benicio Del Toro',
#                 ' Bradley Cooper',
#                 ' Carrie Coon',
#                 ' Chadwick Boseman',
#                 ' Chris Evans',
#                 ' Chris Hemsworth',
#                 ' Chris Pratt',
#                 ' Cobie Smulders',
#                 ' Danai Gurira',
#                 ' Dave Bautista',
#                 ' Don Cheadle',
#                 ' Elizabeth Olsen',
#                 ' Gwyneth Paltrow',
#                 ' Josh Brolin',
#                 ' Karen Gillan',
#                 ' Letitia Wright',
#                 ' Linda Cardellini',
#                 ' Mark Ruffalo',
#                 ' Peter Dinklage',
#                 ' Pom Klementieff',
#                 ' Robert Downey Jr.',
#                 ' Scarlett Johansson',
#                 ' Sebastian Stan',
#                 ' Tessa Thompson',
#                 ' Tom Hiddleston',
#                 ' Tom Holland',
#                 ' Vin Diesel',
#                 ' Winston Duke',
#                 ' Zoe Saldana'],
#   'parental_rating': 'PG-13',
#   'release_date': 'April 27, 2018',
#   'runtime': '149 min',
#   'studio': 'Walt Disney Studios Motion Pictures',
#   'title': 'Avengers: Infinity War',
#   'user_score': '8.6'},
#  {'critic_score': '75',
#   'director': 'James Cameron',
#   'genres': ['Drama', 'Romance'],
#   'main_cast': ['Kate Winslet', ' Leonardo DiCaprio'],
#   'parental_rating': 'PG-13',
#   'release_date': 'December 19, 1997',
#   'runtime': '194 min',
#   'studio': 'Paramount Pictures',
#   'title': 'Titanic',
#   'user_score': '8.5'},
#  {'critic_score': '59',
#   'director': 'Colin Trevorrow',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'main_cast': ['B.D. Wong',
#                 ' BD Wong',
#                 ' Bryce Dallas Howard',
#                 ' Chris Pratt',
#                 ' Irrfan Khan',
#                 ' Judy Greer',
#                 ' Omar Sy',
#                 ' Ty Simpkins',
#                 " Vincent D'Onofrio"],
#   'parental_rating': 'PG-13',
#   'release_date': 'June 12, 2015',
#   'runtime': '124 min',
#   'studio': 'Universal Pictures',
#   'title': 'Jurassic World',
#   'user_score': '6.8'},
#  {'critic_score': '69',
#   'director': 'Joss Whedon',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'main_cast': ['Chris Evans',
#                 ' Jeremy Renner',
#                 ' Robert Downey Jr.',
#                 ' Scarlett Johansson'],
#   'parental_rating': 'PG-13',
#   'release_date': 'May 4, 2012',
#   'runtime': '143 min',
#   'studio': 'Walt Disney Studios Motion Pictures',
#   'title': 'The Avengers',
#   'user_score': '8.0'},
#  {'critic_score': '85',
#   'director': 'Rian Johnson',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Fantasy'],
#   'main_cast': ['Adam Driver',
#                 ' Andy Serkis',
#                 ' Anthony Daniels',
#                 ' Benicio Del Toro',
#                 ' Billie Lourd',
#                 ' Carrie Fisher',
#                 ' Daisy Ridley',
#                 ' Domhnall Gleeson',
#                 ' Gwendoline Christie',
#                 ' John Boyega',
#                 ' Joseph Gordon-Levitt',
#                 ' Laura Dern',
#                 " Lupita Nyong'o",
#                 ' Mark Hamill',
#                 ' Oscar Isaac',
#                 ' Tom Hardy'],
#   'parental_rating': 'PG-13',
#   'release_date': 'December 15, 2017',
#   'runtime': '152 min',
#   'studio': 'Walt Disney Studios Motion Pictures',
#   'title': 'Star Wars Ep. VIII: The Last Jedi',
#   'user_score': '4.5'},
#  {'critic_score': '80',
#   'director': 'Brad Bird',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Comedy', 'Animation', 'Family'],
#   'main_cast': ['Bob Odenkirk',
#                 ' Brad Bird',
#                 ' Catherine Keener',
#                 ' Craig T. Nelson',
#                 ' Eli Fucile',
#                 ' Holly Hunter',
#                 ' Huck Milner',
#                 ' Isabella Rossellini',
#                 ' John Ratzenberger',
#                 ' Jonathan Banks',
#                 ' Michael Bird',
#                 ' Samuel L. Jackson',
#                 ' Sarah Vowell',
#                 ' Sophia Bush'],
#   'parental_rating': 'PG',
#   'release_date': 'June 15, 2018',
#   'runtime': '118 min',
#   'studio': 'Walt Disney Studios Motion Pictures',
#   'title': 'Incredibles 2',
#   'user_score': '8.0'},
#  {'critic_score': '84',
#   'director': 'Christopher Nolan',
#   'genres': ['Action', 'Drama', 'Thriller', 'Crime'],
#   'main_cast': ['Aaron Eckhart', ' Christian Bale', ' Heath Ledger'],
#   'parental_rating': 'PG-13',
#   'release_date': 'July 18, 2008',
#   'runtime': '152 min',
#   'studio': 'Warner Bros. Pictures',
#   'title': 'The Dark Knight',
#   'user_score': '8.9'},
#  {'critic_score': '65',
#   'director': 'Gareth Edwards',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Fantasy', 'War'],
#   'main_cast': ['Alan Tudyk',
#                 ' Ben Mendelsohn',
#                 ' Diego Luna',
#                 ' Donnie Yen',
#                 ' Felicity Jones',
#                 ' Forest Whitaker',
#                 ' Mads Mikkelsen',
#                 ' Riz Ahmed',
#                 ' Wen Jiang'],
#   'parental_rating': 'PG-13',
#   'release_date': 'December 16, 2016',
#   'runtime': '133 min',
#   'studio': 'Walt Disney Studios Motion Pictures',
#   'title': 'Rogue One: A Star Wars Story',
#   'user_score': '7.6'},
#  {'critic_score': '65',
#   'director': 'Bill Condon',
#   'genres': ['Fantasy', 'Romance', 'Family', 'Musical'],
#   'main_cast': ['Dan Stevens',
#                 ' Emma Watson',
#                 ' Gerard Horan',
#                 ' Hattie Morahan',
#                 ' Haydn Gwynne',
#                 ' Josh Gad',
#                 ' Kevin Kline',
#                 ' Luke Evans',
#                 ' Ray Fearon'],
#   'parental_rating': 'PG',
#   'release_date': 'March 17, 2017',
#   'runtime': '129 min',
#   'studio': 'Walt Disney Studios Motion Pictures',
#   'title': 'Beauty and the Beast',
#   'user_score': '6.8'},
#  {'critic_score': '77',
#   'director': 'Andrew Stanton and Angus MacLane',
#   'genres': ['Adventure', 'Comedy', 'Animation', 'Family'],
#   'main_cast': ['Albert Brooks', ' Ellen DeGeneres'],
#   'parental_rating': 'PG',
#   'release_date': 'June 17, 2016',
#   'runtime': '97 min',
#   'studio': 'Walt Disney Studios Motion Pictures',
#   'title': 'Finding Dory',
#   'user_score': '7.4'},
#  {'critic_score': '51',
#   'director': 'George Lucas',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Fantasy'],
#   'main_cast': ['Ewan McGregor', ' Liam Neeson', ' Natalie Portman'],
#   'parental_rating': 'PG',
#   'release_date': 'May 19, 1999',
#   'runtime': '136 min',
#   'studio': 'Twentieth Century Fox Film Corporation',
#   'title': 'Star Wars Ep. I: The Phantom Menace',
#   'user_score': '6.0'},
#  {'critic_score': '90',
#   'director': 'George Lucas',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Fantasy'],
#   'main_cast': ['Carrie Fisher', ' Harrison Ford', ' Mark Hamill'],
#   'parental_rating': 'PG',
#   'release_date': 'May 25, 1977',
#   'runtime': '121 min',
#   'studio': 'Twentieth Century Fox Film Corporation',
#   'title': 'Star Wars Ep. IV: A New Hope',
#   'user_score': '8.8'},
#  {'critic_score': '66',
#   'director': 'Joss Whedon',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller', 'Fantasy'],
#   'main_cast': ['Chris Evans',
#                 ' Chris Hemsworth',
#                 ' James Spader',
#                 ' Jeremy Renner',
#                 ' Mark Ruffalo',
#                 ' Robert Downey Jr.',
#                 ' Samuel L. Jackson',
#                 ' Scarlett Johansson'],
#   'parental_rating': 'PG-13',
#   'release_date': 'May 1, 2015',
#   'runtime': '141 min',
#   'studio': 'Walt Disney Studios Motion Pictures',
#   'title': 'Avengers: Age of Ultron',
#   'user_score': '7.0'},
#  {'critic_score': '78',
#   'director': 'Christopher Nolan',
#   'genres': ['Action', 'Adventure', 'Drama', 'Thriller', 'Crime'],
#   'main_cast': ['Anne Hathaway',
#                 ' Christian Bale',
#                 ' Gary Oldman',
#                 ' Joseph Gordon-Levitt',
#                 ' Marion Cotillard',
#                 ' Michael Caine',
#                 ' Morgan Freeman',
#                 ' Tom Hardy'],
#   'parental_rating': 'PG-13',
#   'release_date': 'July 20, 2012',
#   'runtime': '165 min',
#   'studio': 'Warner Bros. Pictures',
#   'title': 'The Dark Knight Rises',
#   'user_score': '8.2'},
#  {'critic_score': '75',
#   'director': 'Andrew Adamson and Conrad Vernon and Kelly Asbury',
#   'genres': ['Adventure', 'Fantasy', 'Comedy', 'Animation', 'Family'],
#   'main_cast': ['Cameron Diaz', ' Eddie Murphy', ' Mike Myers'],
#   'parental_rating': 'PG',
#   'release_date': 'May 19, 2004',
#   'runtime': '93 min',
#   'studio': 'DreamWorks Distribution',
#   'title': 'Shrek 2',
#   'user_score': '8.7'},
#  {'critic_score': '91',
#   'director': 'Steven Spielberg',
#   'genres': ['Adventure', 'Sci-Fi', 'Drama', 'Fantasy', 'Family'],
#   'main_cast': ['Dee Wallace',
#                 ' Drew Barrymore',
#                 ' Erika Eleniak',
#                 ' Henry Thomas',
#                 ' Peter Coyote'],
#   'parental_rating': 'PG',
#   'release_date': 'June 11, 1982',
#   'runtime': '115 min',
#   'studio': 'Universal Pictures',
#   'title': 'ET: The Extra-Terrestrial',
#   'user_score': '8.3'},
#  {'critic_score': '76',
#   'director': 'Francis Lawrence',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Drama', 'Thriller'],
#   'main_cast': ['Jennifer Lawrence',
#                 ' Josh Hutcherson',
#                 ' Liam Hemsworth',
#                 ' Philip Seymour Hoffman'],
#   'parental_rating': 'PG-13',
#   'release_date': 'November 22, 2013',
#   'runtime': '146 min',
#   'studio': 'Lionsgate',
#   'title': 'The Hunger Games: Catching Fire',
#   'user_score': '7.9'},
#  {'critic_score': '53',
#   'director': 'Gore Verbinski',
#   'genres': ['Action', 'Adventure', 'Fantasy'],
#   'main_cast': ['Johnny Depp', ' Keira Knightley', ' Orlando Bloom'],
#   'parental_rating': 'PG-13',
#   'release_date': 'July 7, 2006',
#   'runtime': '151 min',
#   'studio': 'American Broadcasting Company (ABC)',
#   'title': 'Pirates of the Caribbean: Dead Manâ\x80\x99s Chest',
#   'user_score': '7.2'},
#  {'critic_score': '83',
#   'director': 'Rob Minkoff and Roger Allers',
#   'genres': ['Adventure', 'Drama', 'Animation', 'Family', 'Musical'],
#   'main_cast': ['James Earl Jones',
#                 ' Jeremy Irons',
#                 ' Matthew Broderick',
#                 ' Whoopi Goldberg'],
#   'parental_rating': 'G',
#   'release_date': 'June 15, 1994',
#   'runtime': '89 min',
#   'studio': 'Buena Vista Pictures',
#   'title': 'The Lion King',
#   'user_score': '8.8'},
#  {'critic_score': '51',
#   'director': 'Juan Antonio Bayona',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'main_cast': ['BD Wong',
#                 ' Bryce Dallas Howard',
#                 ' Chris Pratt',
#                 ' Daniel Stisen',
#                 ' Daniella Pineda',
#                 ' Geraldine Chaplin',
#                 ' James Cromwell',
#                 ' Jeff Goldblum',
#                 ' Justice Smith',
#                 ' Kamil Lemieszewski',
#                 ' Rafe Spall',
#                 ' Ted Levine',
#                 ' Toby Jones'],
#   'parental_rating': 'PG-13',
#   'release_date': 'June 22, 2018',
#   'runtime': '128 min',
#   'studio': 'Universal Pictures',
#   'title': 'Jurassic World: Fallen Kingdom',
#   'user_score': '5.6'},
#  {'critic_score': '92',
#   'director': 'Lee Unkrich',
#   'genres': ['Adventure', 'Fantasy', 'Comedy', 'Animation', 'Family'],
#   'main_cast': ['Tim Allen', ' Tom Hanks'],
#   'parental_rating': 'G',
#   'release_date': 'June 18, 2010',
#   'runtime': '103 min',
#   'studio': 'Walt Disney Studios Motion Pictures',
#   'title': 'Toy Story 3',
#   'user_score': '8.9'},
#  {'critic_score': '76',
#   'director': 'Patty Jenkins',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Fantasy', 'War'],
#   'main_cast': ['Chris Pine',
#                 ' Connie Nielsen',
#                 ' Danny Huston',
#                 ' David Thewlis',
#                 ' Eugene Brave Rock',
#                 ' Ewen Bremner',
#                 ' Gal Gadot',
#                 ' Lucy Davis',
#                 ' Robin Wright',
#                 ' Saïd Taghmaoui'],
#   'parental_rating': 'PG-13',
#   'release_date': 'June 2, 2017',
#   'runtime': '141 min',
#   'studio': 'Warner Bros.',
#   'title': 'Wonder Woman',
#   'user_score': '7.7'},
#  {'critic_score': '62',
#   'director': 'Shane Black',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller', 'Fantasy'],
#   'main_cast': ['Don Cheadle',
#                 ' Guy Pearce',
#                 ' Gwyneth Paltrow',
#                 ' Robert Downey Jr.'],
#   'parental_rating': 'PG-13',
#   'release_date': 'May 3, 2013',
#   'runtime': '130 min',
#   'studio': 'Walt Disney Studios Motion Pictures',
#   'title': 'Iron Man 3',
#   'user_score': '6.5'},
#  {'critic_score': '75',
#   'director': 'Anthony Russo and Joe Russo',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'main_cast': ['Anthony Mackie',
#                 ' Chadwick Boseman',
#                 ' Chris Evans',
#                 ' Don Cheadle',
#                 ' Jeremy Renner',
#                 ' Paul Bettany',
#                 ' Robert Downey Jr.',
#                 ' Scarlett Johansson',
#                 ' Sebastian Stan'],
#   'parental_rating': 'PG-13',
#   'release_date': 'May 6, 2016',
#   'runtime': '147 min',
#   'studio': 'Walt Disney Studios Motion Pictures',
#   'title': 'Captain America: Civil War',
#   'user_score': '8.2'},
#  {'critic_score': '68',
#   'director': 'Gary Ross',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Drama', 'Thriller'],
#   'main_cast': ['Jennifer Lawrence', ' Josh Hutcherson', ' Liam Hemsworth'],
#   'parental_rating': 'PG-13',
#   'release_date': 'March 23, 2012',
#   'runtime': '142 min',
#   'studio': 'Lionsgate',
#   'title': 'The Hunger Games',
#   'user_score': '7.0'},
#  {'critic_score': '58',
#   'director': 'Jake Kasdan',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Comedy', 'Family'],
#   'main_cast': ['Alex Wolff',
#                 ' Bobby Cannavale',
#                 ' Dwayne Johnson',
#                 ' Jack Black',
#                 ' Karen Gillan',
#                 ' Kevin Hart',
#                 ' Madison Iseman',
#                 ' Marc Evan Jackson',
#                 ' Maribeth Monroe',
#                 ' Missi Pyle',
#                 ' Nick Jonas',
#                 ' Rhys Darby',
#                 " Ser'Darius William Blain",
#                 ' Sylvia Jefferies',
#                 ' Tim Matheson'],
#   'parental_rating': 'PG-13',
#   'release_date': 'December 20, 2017',
#   'runtime': '119 min',
#   'studio': 'Columbia Pictures',
#   'title': 'Jumanji: Welcome to the Jungle',
#   'user_score': '6.7'},
#  {'critic_score': '73',
#   'director': 'Sam Raimi',
#   'genres': ['Action', 'Adventure', 'Fantasy'],
#   'main_cast': ['Kirsten Dunst', ' Tobey Maguire'],
#   'parental_rating': 'PG-13',
#   'release_date': 'May 3, 2002',
#   'runtime': '121 min',
#   'studio': 'Columbia Pictures',
#   'title': 'Spider-Man',
#   'user_score': '8.6'},
#  {'critic_score': '35',
#   'director': 'Michael Bay',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'main_cast': ['Josh Duhamel', ' Megan Fox', ' Shia LaBeouf'],
#   'parental_rating': 'PG-13',
#   'release_date': 'June 24, 2009',
#   'runtime': '150 min',
#   'studio': 'Paramount Pictures',
#   'title': 'Transformers: Revenge of the Fallen',
#   'user_score': '5.3'},
#  {'critic_score': '74',
#   'director': 'Chris Buck and Jennifer Lee',
#   'genres': ['Action',
#              'Adventure',
#              'Mystery',
#              'Thriller',
#              'Fantasy',
#              'Comedy',
#              'Romance',
#              'Animation',
#              'Family',
#              'Musical'],
#   'main_cast': ['Idina Menzel', ' Josh Gad', ' Kristen Bell'],
#   'parental_rating': 'PG',
#   'release_date': 'November 27, 2013',
#   'runtime': '102 min',
#   'studio': 'Walt Disney Studios Motion Pictures',
#   'title': 'Frozen',
#   'user_score': '7.5'},
#  {'critic_score': '68',
#   'director': 'Steven Spielberg',
#   'genres': ['Adventure', 'Sci-Fi', 'Thriller'],
#   'main_cast': ['Jeff Goldblum',
#                 ' Laura Dern',
#                 ' Richard Attenborough',
#                 ' Sam Neill'],
#   'parental_rating': 'PG-13',
#   'release_date': 'June 11, 1993',
#   'runtime': '127 min',
#   'studio': 'Universal Pictures',
#   'title': 'Jurassic Park',
#   'user_score': '8.8'},
#  {'critic_score': '67',
#   'director': 'James Gunn',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Comedy'],
#   'main_cast': ['Bradley Cooper',
#                 ' Chris Pratt',
#                 ' Dave Bautista',
#                 ' Karen Gillan',
#                 ' Michael Rooker',
#                 ' Pom Klementieff',
#                 ' Sylvester Stallone',
#                 ' Vin Diesel',
#                 ' Zoe Saldana'],
#   'parental_rating': 'PG-13',
#   'release_date': 'May 5, 2017',
#   'runtime': '136 min',
#   'studio': 'Walt Disney Studios Motion Pictures',
#   'title': 'Guardians of the Galaxy Vol 2',
#   'user_score': '7.7'},
#  {'critic_score': '87',
#   'director': 'David Yates',
#   'genres': ['Adventure', 'Mystery', 'Fantasy'],
#   'main_cast': ['Daniel Radcliffe',
#                 ' Emma Watson',
#                 ' Michael Gambon',
#                 ' Rupert Grint'],
#   'parental_rating': 'PG-13',
#   'release_date': 'July 15, 2011',
#   'runtime': '130 min',
#   'studio': 'Warner Bros. Pictures',
#   'title': 'Harry Potter and the Deathly Hallows: Part II',
#   'user_score': '8.1'},
#  {'critic_score': '90',
#   'director': 'Andrew Stanton and Lee Unkrich',
#   'genres': ['Adventure', 'Comedy', 'Animation', 'Family'],
#   'main_cast': ['Albert Brooks', ' Alexander Gould', ' Ellen DeGeneres'],
#   'parental_rating': 'G',
#   'release_date': 'May 30, 2003',
#   'runtime': '100 min',
#   'studio': 'Buena Vista Pictures',
#   'title': 'Finding Nemo',
#   'user_score': '8.7'},
#  {'critic_score': '68',
#   'director': 'George Lucas',
#   'genres': ['Action', 'Sci-Fi', 'Fantasy'],
#   'main_cast': ['Ewan McGregor', ' Hayden Christensen', ' Natalie Portman'],
#   'parental_rating': 'PG-13',
#   'release_date': 'May 19, 2005',
#   'runtime': '140 min',
#   'studio': 'Twentieth Century Fox Film Corporation',
#   'title': 'Star Wars Ep. III: Revenge of the Sith',
#   'user_score': '7.6'},
#  {'critic_score': '94',
#   'director': 'Peter Jackson',
#   'genres': ['Action', 'Adventure', 'Fantasy'],
#   'main_cast': ['Andy Serkis', ' Orlando Bloom'],
#   'parental_rating': 'PG-13',
#   'release_date': 'December 17, 2003',
#   'runtime': '201 min',
#   'studio': 'New Line Cinema',
#   'title': 'The Lord of the Rings: The Return of the King',
#   'user_score': '9.1'},
#  {'critic_score': '95',
#   'director': 'Gary Trousdale and Kirk Wise',
#   'genres': ['Fantasy', 'Romance', 'Animation', 'Family', 'Musical'],
#   'main_cast': ["Paige O'Hara", ' Robby Benson'],
#   'parental_rating': 'G',
#   'release_date': 'November 22, 1991',
#   'runtime': '84 min',
#   'studio': 'Buena Vista Pictures',
#   'title': 'Beauty and the Beast',
#   'user_score': '8.7'},
#  {'critic_score': '83',
#   'director': 'Sam Raimi',
#   'genres': ['Action', 'Sci-Fi', 'Thriller', 'Fantasy'],
#   'main_cast': ['Alfred Molina', ' Kirsten Dunst', ' Tobey Maguire'],
#   'parental_rating': 'PG-13',
#   'release_date': 'June 30, 2004',
#   'runtime': '127 min',
#   'studio': 'Columbia Pictures',
#   'title': 'Spider-Man 2',
#   'user_score': '8.6'},
#  {'critic_score': '47',
#   'director': 'Mel Gibson',
#   'genres': ['Drama', 'History'],
#   'main_cast': ['James Caviezel', ' Monica Bellucci'],
#   'parental_rating': 'Unrated',
#   'release_date': 'February 25, 2004',
#   'runtime': '127 min',
#   'studio': 'Newmarket Films',
#   'title': 'The Passion of the Christ',
#   'user_score': '6.5'},
#  {'critic_score': '61',
#   'director': 'Chris Renaud and Yarrow Cheney',
#   'genres': ['Adventure', 'Comedy', 'Animation', 'Family'],
#   'main_cast': ['Ellie Kemper',
#                 ' Eric Stonestreet',
#                 ' Kevin Hart',
#                 ' Lake Bell',
#                 ' Louis C.K.'],
#   'parental_rating': 'PG',
#   'release_date': 'July 8, 2016',
#   'runtime': '87 min',
#   'studio': 'Universal Pictures',
#   'title': 'The Secret Life of Pets',
#   'user_score': '6.2'},
#  {'critic_score': '62',
#   'director': 'Chris Renaud and Pierre Coffin',
#   'genres': ['Adventure', 'Sci-Fi', 'Comedy', 'Crime', 'Animation', 'Family'],
#   'main_cast': ['Al Pacino', ' Kristen Wiig', ' Steve Carell'],
#   'parental_rating': 'PG',
#   'release_date': 'July 3, 2013',
#   'runtime': '98 min',
#   'studio': 'Universal Pictures',
#   'title': 'Despicable Me 2',
#   'user_score': '7.2'},
#  {'critic_score': '77',
#   'director': 'Jon Favreau',
#   'genres': ['Adventure', 'Drama', 'Fantasy', 'Family', 'Musical'],
#   'main_cast': ['Ben Kingsley',
#                 ' Bill Murray',
#                 ' Giancarlo Esposito',
#                 ' Idris Elba',
#                 " Lupita Nyong'o",
#                 ' Neel Sethi',
#                 ' Scarlett Johansson'],
#   'parental_rating': 'PG',
#   'release_date': 'April 15, 2016',
#   'runtime': '106 min',
#   'studio': 'Walt Disney Studios Motion Pictures',
#   'title': 'The Jungle Book',
#   'user_score': '7.5'},
#  {'critic_score': '65',
#   'director': 'Tim Miller',
#   'genres': ['Action',
#              'Adventure',
#              'Sci-Fi',
#              'Thriller',
#              'Fantasy',
#              'Comedy',
#              'Romance'],
#   'main_cast': ['Ed Skrein',
#                 ' Morena Baccarin',
#                 ' Ryan Reynolds',
#                 ' T.J. Miller'],
#   'parental_rating': 'R',
#   'release_date': 'February 12, 2016',
#   'runtime': '108 min',
#   'studio': 'Twentieth Century Fox Film Corporation',
#   'title': 'Deadpool',
#   'user_score': '8.1'},
#  {'critic_score': '94',
#   'director': 'Pete Docter and Ronaldo Del Carmen',
#   'genres': ['Adventure', 'Drama', 'Fantasy', 'Comedy', 'Animation', 'Family'],
#   'main_cast': ['Amy Poehler',
#                 ' Bill Hader',
#                 ' Lewis Black',
#                 ' Mindy Kaling',
#                 ' Phyllis Smith'],
#   'parental_rating': 'PG',
#   'release_date': 'June 19, 2015',
#   'runtime': '94 min',
#   'studio': 'Walt Disney Studios Motion Pictures',
#   'title': 'Inside Out',
#   'user_score': '8.7'},
#  {'critic_score': '67',
#   'director': 'James Wan',
#   'genres': ['Action', 'Adventure', 'Thriller', 'Crime'],
#   'main_cast': ['Dwayne Johnson',
#                 ' Jason Statham',
#                 ' Paul Walker',
#                 ' Tyrese Gibson',
#                 ' Vin Diesel'],
#   'parental_rating': 'PG-13',
#   'release_date': 'April 3, 2015',
#   'runtime': '137 min',
#   'studio': 'Universal Pictures',
#   'title': 'Furious 7',
#   'user_score': '6.8'},
#  {'critic_score': '42',
#   'director': 'Michael Bay',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'main_cast': ['Josh Duhamel',
#                 ' Rosie Huntington-Whiteley',
#                 ' Shia LaBeouf',
#                 ' Tyrese Gibson'],
#   'parental_rating': 'PG-13',
#   'release_date': 'June 29, 2011',
#   'runtime': '154 min',
#   'studio': 'Paramount Pictures',
#   'title': 'Transformers: Dark of the Moon',
#   'user_score': '5.7'},
#  {'critic_score': '72',
#   'director': 'Clint Eastwood',
#   'genres': ['Action', 'Biography', 'Drama', 'War'],
#   'main_cast': ['Bradley Cooper', ' Sienna Miller'],
#   'parental_rating': 'R',
#   'release_date': 'December 25, 2014',
#   'runtime': '132 min',
#   'studio': 'Warner Bros. Pictures',
#   'title': 'American Sniper',
#   'user_score': '6.6'},
#  {'critic_score': '87',
#   'director': 'Peter Jackson',
#   'genres': ['Action', 'Adventure', 'Fantasy'],
#   'main_cast': ['Andy Serkis'],
#   'parental_rating': 'PG-13',
#   'release_date': 'December 18, 2002',
#   'runtime': '179 min',
#   'studio': 'New Line Cinema',
#   'title': 'The Lord of the Rings: The Two Towers',
#   'user_score': '9.0'},
#  {'critic_score': '78',
#   'director': 'Byron Howard and Jared Bush and Rich Moore',
#   'genres': ['Action', 'Adventure', 'Comedy', 'Crime', 'Animation', 'Family'],
#   'main_cast': '',
#   'parental_rating': 'PG',
#   'release_date': 'March 4, 2016',
#   'runtime': '108 min',
#   'studio': 'Walt Disney Studios Motion Pictures',
#   'title': 'Zootopia',
#   'user_score': '8.7'},
#  {'critic_score': '64',
#   'director': 'Francis Lawrence',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Drama', 'Thriller'],
#   'main_cast': ['Donald Sutherland',
#                 ' Elizabeth Banks',
#                 ' Jennifer Lawrence',
#                 ' Josh Hutcherson',
#                 ' Julianne Moore',
#                 ' Liam Hemsworth',
#                 ' Philip Seymour Hoffman',
#                 ' Woody Harrelson'],
#   'parental_rating': 'PG-13',
#   'release_date': 'November 21, 2014',
#   'runtime': '123 min',
#   'studio': 'Lionsgate',
#   'title': 'The Hunger Games: Mockingjay - Part 1',
#   'user_score': '6.3'},
#  {'critic_score': '59',
#   'director': 'Sam Raimi',
#   'genres': ['Action', 'Thriller'],
#   'main_cast': ['James Franco',
#                 ' Kirsten Dunst',
#                 ' Thomas Haden Church',
#                 ' Tobey Maguire',
#                 ' Topher Grace'],
#   'parental_rating': 'PG-13',
#   'release_date': 'May 4, 2007',
#   'runtime': '139 min',
#   'studio': 'Columbia Pictures',
#   'title': 'Spider-Man 3',
#   'user_score': '6.7'},
#  {'critic_score': '56',
#   'director': 'Kyle Balda and Pierre Coffin',
#   'genres': ['Comedy', 'Animation', 'Family'],
#   'main_cast': ['Allison Janney',
#                 ' Chris Renaud',
#                 ' Geoffrey Rush',
#                 ' Jon Hamm',
#                 ' Michael Keaton',
#                 ' Pierre Coffin',
#                 ' Sandra Bullock',
#                 ' Steve Carell'],
#   'parental_rating': 'PG',
#   'release_date': 'July 10, 2015',
#   'runtime': '91 min',
#   'studio': 'Universal Pictures',
#   'title': 'Minions',
#   'user_score': '5.6'},
#  {'critic_score': '73',
#   'director': 'Jon Watts',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Fantasy', 'Family'],
#   'main_cast': ['Donald Glover',
#                 ' Gwyneth Paltrow',
#                 ' Jacob Batalon',
#                 ' Jon Favreau',
#                 ' Laura Harrier',
#                 ' Marisa Tomei',
#                 ' Michael Keaton',
#                 ' Robert Downey Jr.',
#                 ' Tom Holland',
#                 ' Zendaya'],
#   'parental_rating': 'PG-13',
#   'release_date': 'July 7, 2017',
#   'runtime': '133 min',
#   'studio': 'Columbia Pictures',
#   'title': 'Spider-Man: Homecoming',
#   'user_score': '7.6'},
#  {'critic_score': '53',
#   'director': 'Tim Burton',
#   'genres': ['Adventure', 'Fantasy', 'Family'],
#   'main_cast': ['Johnny Depp', ' Mia Wasikowska'],
#   'parental_rating': 'PG',
#   'release_date': 'March 5, 2010',
#   'runtime': '108 min',
#   'studio': 'Walt Disney Studios Motion Pictures',
#   'title': 'Alice in Wonderland',
#   'user_score': '5.8'},
#  {'critic_score': '76',
#   'director': 'James Gunn',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'main_cast': ['Bradley Cooper',
#                 ' Chris Pratt',
#                 ' Dave Bautista',
#                 ' Lee Pace',
#                 ' Vin Diesel',
#                 ' Zoe Saldana'],
#   'parental_rating': 'PG-13',
#   'release_date': 'August 1, 2014',
#   'runtime': '121 min',
#   'studio': 'Walt Disney Studios Motion Pictures',
#   'title': 'Guardians of the Galaxy',
#   'user_score': '8.6'},
#  {'critic_score': '44',
#   'director': 'Zack Snyder',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Fantasy'],
#   'main_cast': ['Amy Adams',
#                 ' Ben Affleck',
#                 ' Henry Cavill',
#                 ' Jason Momoa',
#                 ' Jesse Eisenberg'],
#   'parental_rating': 'R',
#   'release_date': 'March 25, 2016',
#   'runtime': '151 min',
#   'studio': 'Warner Bros.',
#   'title': 'Batman v Superman: Dawn of Justice',
#   'user_score': '7.0'},
#  {'critic_score': '82',
#   'director': 'Robert Zemeckis',
#   'genres': ['Drama', 'Romance'],
#   'main_cast': ['Gary Sinise', ' Robin Wright', ' Sally Field', ' Tom Hanks'],
#   'parental_rating': 'PG-13',
#   'release_date': 'July 6, 1994',
#   'runtime': '142 min',
#   'studio': 'Paramount Pictures',
#   'title': 'Forrest Gump',
#   'user_score': '7.7'},
#  {'critic_score': '69',
#   'director': 'Andres Muschietti',
#   'genres': ['Adventure', 'Drama', 'Thriller', 'Horror'],
#   'main_cast': ['Bill Skarsgård',
#                 ' Chosen Jacobs',
#                 ' Finn Wolfhard',
#                 ' Jack Grazer',
#                 ' Jaeden Lieberher',
#                 ' Jake Sim',
#                 ' Javier Botet',
#                 ' Jeremy Ray Taylor',
#                 ' Megan Charpentier',
#                 ' Nicholas Hamilton',
#                 ' Owen Teague',
#                 ' Sophia Lillis',
#                 ' Steven Williams',
#                 ' Wyatt Oleff'],
#   'parental_rating': 'R',
#   'release_date': 'September 8, 2017',
#   'runtime': '135 min',
#   'studio': 'New Line Cinema',
#   'title': 'It',
#   'user_score': '7.8'},
#  {'critic_score': '40',
#   'director': 'David Ayer',
#   'genres': ['Action',
#              'Adventure',
#              'Sci-Fi',
#              'Thriller',
#              'Fantasy',
#              'Comedy',
#              'Crime'],
#   'main_cast': ['Jared Leto', ' Margot Robbie', ' Viola Davis', ' Will Smith'],
#   'parental_rating': 'PG-13',
#   'release_date': 'August 5, 2016',
#   'runtime': '123 min',
#   'studio': 'Warner Bros.',
#   'title': 'Suicide Squad',
#   'user_score': '6.1'},
#  {'critic_score': '66',
#   'director': 'David Leitch',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Comedy'],
#   'main_cast': ['Bill Skarsgård',
#                 ' Brad Pitt',
#                 ' Brianna Hildebrand',
#                 ' Eddie Marsan',
#                 ' Hayley Sales',
#                 ' Jack Kesy',
#                 ' Josh Brolin',
#                 ' Julian Dennison',
#                 ' Karan Soni',
#                 ' Leslie Uggams',
#                 ' Lewis Tan',
#                 ' Matt Damon',
#                 ' Morena Baccarin',
#                 ' Rob Delaney',
#                 ' Ryan Reynolds',
#                 ' Shiori Kutsuna',
#                 ' Stefan Kapicic',
#                 ' T.J. Miller',
#                 ' Terry Crews',
#                 ' Zazie Beetz'],
#   'parental_rating': 'R',
#   'release_date': 'May 18, 2018',
#   'runtime': '119 min',
#   'studio': '',
#   'title': 'Deadpool 2',
#   'user_score': '7.7'},
#  {'critic_score': '58',
#   'director': 'Chris Miller and Raman Hui',
#   'genres': ['Adventure', 'Fantasy', 'Comedy', 'Animation', 'Family'],
#   'main_cast': ['Cameron Diaz', ' Eddie Murphy', ' Mike Myers'],
#   'parental_rating': 'PG',
#   'release_date': 'May 18, 2007',
#   'runtime': '93 min',
#   'studio': 'Paramount Pictures',
#   'title': 'Shrek the Third',
#   'user_score': '6.5'},
#  {'critic_score': '61',
#   'director': 'Michael Bay',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller', 'Comedy'],
#   'main_cast': ['Josh Duhamel', ' Megan Fox', ' Shia LaBeouf'],
#   'parental_rating': 'PG-13',
#   'release_date': 'July 3, 2007',
#   'runtime': '144 min',
#   'studio': 'Paramount Pictures',
#   'title': 'Transformers',
#   'user_score': '6.9'},
#  {'critic_score': '79',
#   'director': 'Jon Favreau',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'main_cast': ['Gwyneth Paltrow', ' Robert Downey Jr.', ' Terrence Howard'],
#   'parental_rating': 'PG-13',
#   'release_date': 'May 2, 2008',
#   'runtime': '126 min',
#   'studio': 'Paramount Pictures',
#   'title': 'Iron Man',
#   'user_score': '8.5'},
#  {'critic_score': '64',
#   'director': 'Chris Columbus',
#   'genres': ['Adventure', 'Mystery', 'Fantasy', 'Family'],
#   'main_cast': ['Daniel Radcliffe'],
#   'parental_rating': 'TV-G',
#   'release_date': 'November 16, 2001',
#   'runtime': '152 min',
#   'studio': 'Warner Bros. Pictures',
#   'title': 'Harry Potter and the Sorcererâ\x80\x99s Stone',
#   'user_score': '7.8'},
#  {'critic_score': '65',
#   'director': 'Steven Spielberg',
#   'genres': ['Action', 'Adventure', 'Thriller'],
#   'main_cast': ['Cate Blanchett', ' Harrison Ford', ' Shia LaBeouf'],
#   'parental_rating': 'PG-13',
#   'release_date': 'May 22, 2008',
#   'runtime': '122 min',
#   'studio': 'Paramount Pictures',
#   'title': 'Indiana Jones and the Kingdom of the Crystal Skull',
#   'user_score': '5.4'},
#  {'critic_score': '92',
#   'director': 'Peter Jackson',
#   'genres': ['Action', 'Adventure', 'Fantasy'],
#   'main_cast': ['Andy Serkis', ' Elijah Wood'],
#   'parental_rating': 'PG-13',
#   'release_date': 'December 19, 2001',
#   'runtime': '178 min',
#   'studio': 'New Line Cinema',
#   'title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'user_score': '9.1'},
#  {'critic_score': '74',
#   'director': 'Taika Waititi',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Drama', 'Fantasy', 'Comedy'],
#   'main_cast': ['Anthony Hopkins',
#                 ' Benedict Cumberbatch',
#                 ' Cate Blanchett',
#                 ' Chris Hemsworth',
#                 ' Clancy Brown',
#                 ' Idris Elba',
#                 ' Jaimie Alexander',
#                 ' Jeff Goldblum',
#                 ' Karl Urban',
#                 ' Mark Ruffalo',
#                 ' Sam Neill',
#                 ' Taika Waititi',
#                 ' Tessa Thompson',
#                 ' Tom Hiddleston'],
#   'parental_rating': 'PG-13',
#   'release_date': 'November 3, 2017',
#   'runtime': '130 min',
#   'studio': 'Walt Disney Studios Motion Pictures',
#   'title': 'Thor: Ragnarok',
#   'user_score': '7.7'},
#  {'critic_score': '57',
#   'director': 'Jon Favreau',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'main_cast': ['Gwyneth Paltrow', ' Mickey Rourke', ' Robert Downey Jr.'],
#   'parental_rating': 'PG-13',
#   'release_date': 'May 7, 2010',
#   'runtime': '124 min',
#   'studio': 'Paramount Pictures',
#   'title': 'Iron Man 2',
#   'user_score': '6.4'},
#  {'critic_score': '54',
#   'director': 'George Lucas',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Fantasy'],
#   'main_cast': ['Ewan McGregor', ' Natalie Portman'],
#   'parental_rating': 'PG',
#   'release_date': 'May 16, 2002',
#   'runtime': '142 min',
#   'studio': 'Twentieth Century Fox Film Corporation',
#   'title': 'Star Wars Ep. II: Attack of the Clones',
#   'user_score': '6.0'},
#  {'critic_score': '50',
#   'director': 'Gore Verbinski',
#   'genres': ['Action', 'Adventure', 'Fantasy'],
#   'main_cast': ['Johnny Depp', ' Keira Knightley', ' Orlando Bloom'],
#   'parental_rating': 'PG-13',
#   'release_date': 'May 25, 2007',
#   'runtime': '169 min',
#   'studio': 'Buena Vista Pictures',
#   'title': 'Pirates of the Caribbean: At Worldâ\x80\x99s End',
#   'user_score': '6.3'},
#  {'critic_score': '58',
#   'director': 'Richard Marquand',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller', 'Fantasy'],
#   'main_cast': ['Carrie Fisher', ' Harrison Ford', ' Mark Hamill'],
#   'parental_rating': 'PG',
#   'release_date': 'May 25, 1983',
#   'runtime': '134 min',
#   'studio': 'Twentieth Century Fox Film Corporation',
#   'title': 'Star Wars Ep. VI: Return of the Jedi',
#   'user_score': '8.3'},
#  {'critic_score': '59',
#   'director': 'Roland Emmerich',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'main_cast': ['Bill Pullman',
#                 ' Jeff Goldblum',
#                 ' Mary McDonnell',
#                 ' Will Smith'],
#   'parental_rating': 'PG-13',
#   'release_date': 'July 3, 1996',
#   'runtime': '145 min',
#   'studio': 'Twentieth Century Fox Film Corporation',
#   'title': 'Independence Day',
#   'user_score': '6.9'},
#  {'critic_score': '63',
#   'director': 'Gore Verbinski',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Romance', 'Family'],
#   'main_cast': ['Geoffrey Rush',
#                 ' Johnny Depp',
#                 ' Jonathan Pryce',
#                 ' Keira Knightley',
#                 ' Orlando Bloom'],
#   'parental_rating': 'PG-13',
#   'release_date': 'July 9, 2003',
#   'runtime': '143 min',
#   'studio': 'Buena Vista Pictures',
#   'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'user_score': '8.8'},
#  {'critic_score': '81',
#   'director': 'Sam Mendes',
#   'genres': ['Action', 'Adventure', 'Thriller', 'Crime'],
#   'main_cast': ['Daniel Craig',
#                 ' Helen McCrory',
#                 ' Javier Bardem',
#                 ' Judi Dench',
#                 ' Naomie Harris',
#                 ' Ralph Fiennes'],
#   'parental_rating': 'PG-13',
#   'release_date': 'November 9, 2012',
#   'runtime': '143 min',
#   'studio': 'Columbia Pictures',
#   'title': 'Skyfall',
#   'user_score': '7.7'},
#  {'critic_score': '58',
#   'director': 'Peter Jackson',
#   'genres': ['Adventure', 'Fantasy'],
#   'main_cast': ['Andy Serkis',
#                 ' Graham McTavish',
#                 ' Ian McKellen',
#                 ' Ken Stott',
#                 ' Martin Freeman',
#                 ' Richard Armitage'],
#   'parental_rating': 'PG-13',
#   'release_date': 'December 14, 2012',
#   'runtime': '169 min',
#   'studio': 'Warner Bros. Pictures',
#   'title': 'The Hobbit: An Unexpected Journey',
#   'user_score': '8.0'},
#  {'critic_score': '78',
#   'director': 'David Yates',
#   'genres': ['Action', 'Adventure', 'Mystery', 'Fantasy', 'Romance', 'Family'],
#   'main_cast': ['Daniel Radcliffe', ' Emma Watson', ' Rupert Grint'],
#   'parental_rating': 'PG',
#   'release_date': 'July 15, 2009',
#   'runtime': '153 min',
#   'studio': 'Warner Bros. Pictures',
#   'title': 'Harry Potter and the Half-Blood Prince',
#   'user_score': '7.2'},
#  {'critic_score': '58',
#   'director': 'David Slade',
#   'genres': ['Sci-Fi', 'Drama', 'Thriller', 'Fantasy', 'Romance'],
#   'main_cast': ['Kristen Stewart', ' Robert Pattinson', ' Taylor Lautner'],
#   'parental_rating': 'PG-13',
#   'release_date': 'June 30, 2010',
#   'runtime': '124 min',
#   'studio': 'Summit Entertainment',
#   'title': 'The Twilight Saga: Eclipse',
#   'user_score': '5.1'},
#  {'critic_score': '44',
#   'director': 'Chris Weitz',
#   'genres': ['Drama', 'Fantasy', 'Romance'],
#   'main_cast': ['Kristen Stewart', ' Robert Pattinson', ' Taylor Lautner'],
#   'parental_rating': 'PG-13',
#   'release_date': 'November 20, 2009',
#   'runtime': '130 min',
#   'studio': 'Summit Entertainment',
#   'title': 'The Twilight Saga: New Moon',
#   'user_score': '4.1'},
#  {'critic_score': '65',
#   'director': 'David Yates',
#   'genres': ['Action', 'Adventure', 'Mystery', 'Fantasy'],
#   'main_cast': ['Daniel Radcliffe', ' Emma Watson', ' Rupert Grint'],
#   'parental_rating': 'PG-13',
#   'release_date': 'November 19, 2010',
#   'runtime': '146 min',
#   'studio': 'Warner Bros. Pictures',
#   'title': 'Harry Potter and the Deathly Hallows: Part I',
#   'user_score': '7.6'},
#  {'critic_score': '64',
#   'director': 'M. Night Shyamalan',
#   'genres': ['Drama', 'Mystery', 'Thriller'],
#   'main_cast': ['Bruce Willis', ' Haley Joel Osment'],
#   'parental_rating': 'PG-13',
#   'release_date': 'August 6, 1999',
#   'runtime': '107 min',
#   'studio': 'Buena Vista Pictures',
#   'title': 'The Sixth Sense',
#   'user_score': '8.9'},
#  {'critic_score': '88',
#   'director': 'Bob Peterson and Pete Docter',
#   'genres': ['Adventure', 'Drama', 'Comedy', 'Animation', 'Family'],
#   'main_cast': ['Edward Asner', ' John Ratzenberger', ' Jordan Nagai'],
#   'parental_rating': 'PG',
#   'release_date': 'May 29, 2009',
#   'runtime': '96 min',
#   'studio': 'Walt Disney Studios Motion Pictures',
#   'title': 'Up',
#   'user_score': '8.8'},
#  {'critic_score': '55',
#   'director': 'James Wan',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Fantasy'],
#   'main_cast': ['Amber Heard',
#                 ' Djimon Hounsou',
#                 ' Dolph Lundgren',
#                 ' Graham McTavish',
#                 ' Jason Momoa',
#                 ' Julie Andrews',
#                 ' Leigh Whannell',
#                 ' Ludi Lin',
#                 ' Michael Beach',
#                 ' Nicole Kidman',
#                 ' Patrick Cox',
#                 ' Patrick Wilson',
#                 ' Randall Park',
#                 ' Tahlia Jade',
#                 ' Temuera Morrison',
#                 ' Willem Dafoe',
#                 ' Yahya Abdul-Mateen II'],
#   'parental_rating': 'PG-13',
#   'release_date': 'December 21, 2018',
#   'runtime': '143 min',
#   'studio': 'Warner Bros.',
#   'title': 'Aquaman',
#   'user_score': '7.3'},
#  {'critic_score': '74',
#   'director': 'Christopher Nolan',
#   'genres': ['Action', 'Sci-Fi', 'Drama', 'Mystery', 'Thriller'],
#   'main_cast': ['Ellen Page',
#                 ' Joseph Gordon-Levitt',
#                 ' Ken Watanabe',
#                 ' Leonardo DiCaprio'],
#   'parental_rating': 'PG-13',
#   'release_date': 'July 16, 2010',
#   'runtime': '148 min',
#   'studio': 'Warner Bros. Pictures',
#   'title': 'Inception',
#   'user_score': '8.8'},
#  {'critic_score': '52',
#   'director': 'Bill Condon',
#   'genres': ['Adventure', 'Drama', 'Thriller', 'Fantasy', 'Romance'],
#   'main_cast': ['Kristen Stewart', ' Robert Pattinson', ' Taylor Lautner'],
#   'parental_rating': 'PG-13',
#   'release_date': 'November 16, 2012',
#   'runtime': '115 min',
#   'studio': 'Summit Entertainment',
#   'title': 'The Twilight Saga: Breaking Dawn, Part 2',
#   'user_score': '4.8'},
#  {'critic_score': '71',
#   'director': 'David Yates',
#   'genres': ['Adventure', 'Mystery', 'Fantasy', 'Family'],
#   'main_cast': ['Daniel Radcliffe'],
#   'parental_rating': 'PG-13',
#   'release_date': 'July 11, 2007',
#   'runtime': '138 min',
#   'studio': 'Warner Bros. Pictures',
#   'title': 'Harry Potter and the Order of the Phoenix',
#   'user_score': '7.3'},
#  {'critic_score': '75',
#   'director': 'Andrew Adamson',
#   'genres': ['Adventure', 'Fantasy', 'Family'],
#   'main_cast': ['Anna Popplewell',
#                 ' Georgie Henley',
#                 ' Skandar Keynes',
#                 ' Tilda Swinton',
#                 ' William Moseley'],
#   'parental_rating': 'Unrated',
#   'release_date': 'December 9, 2005',
#   'runtime': '143 min',
#   'studio': 'Buena Vista Pictures',
#   'title': 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#   'user_score': '5.8'},
#  {'critic_score': '55',
#   'director': 'Zack Snyder',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Fantasy'],
#   'main_cast': ['Amy Adams',
#                 ' Antje Traue',
#                 ' Christopher Meloni',
#                 ' Diane Lane',
#                 ' Harry Lennix',
#                 ' Henry Cavill',
#                 ' Michael Shannon',
#                 ' Richard Schiff',
#                 ' Russell Crowe'],
#   'parental_rating': 'PG-13',
#   'release_date': 'June 14, 2013',
#   'runtime': '143 min',
#   'studio': 'Warner Bros. Pictures',
#   'title': 'Man of Steel',
#   'user_score': '7.5'},
#  {'critic_score': '82',
#   'director': 'Irvin Kershner',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'main_cast': ['Carrie Fisher', ' Harrison Ford', ' Mark Hamill'],
#   'parental_rating': 'PG',
#   'release_date': 'May 21, 1980',
#   'runtime': '124 min',
#   'studio': 'Twentieth Century Fox Film Corporation',
#   'title': 'Star Wars Ep. V: The Empire Strikes Back',
#   'user_score': '9.0'},
#  {'critic_score': '81',
#   'director': 'Mike Newell',
#   'genres': ['Adventure', 'Mystery', 'Fantasy', 'Family'],
#   'main_cast': ['Daniel Radcliffe', ' Emma Watson', ' Rupert Grint'],
#   'parental_rating': 'PG-13',
#   'release_date': 'November 18, 2005',
#   'runtime': '157 min',
#   'studio': 'Warner Bros. Pictures',
#   'title': 'Harry Potter and the Goblet of Fire',
#   'user_score': '7.9'},
#  {'critic_score': '78',
#   'director': 'David Silverman and Lee Unkrich and Pete Docter',
#   'genres': ['Adventure', 'Fantasy', 'Comedy', 'Animation', 'Family'],
#   'main_cast': ['Billy Crystal', ' John Goodman'],
#   'parental_rating': 'TV-G',
#   'release_date': 'November 2, 2001',
#   'runtime': '92 min',
#   'studio': 'Buena Vista Pictures',
#   'title': 'Monsters, Inc.',
#   'user_score': '8.7'},
#  {'critic_score': '63',
#   'director': 'Chris Columbus',
#   'genres': ['Comedy', 'Crime', 'Family'],
#   'main_cast': ['Daniel Stern', ' Joe Pesci', ' Macaulay Culkin'],
#   'parental_rating': 'PG',
#   'release_date': 'November 16, 1990',
#   'runtime': '103 min',
#   'studio': 'Twentieth Century Fox Film Corporation',
#   'title': 'Home Alone',
#   'user_score': '8.7'},
#  {'critic_score': '65',
#   'director': 'Francis Lawrence',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Drama', 'Thriller', 'War'],
#   'main_cast': ['Donald Sutherland',
#                 ' Elizabeth Banks',
#                 ' Jennifer Lawrence',
#                 ' Josh Hutcherson',
#                 ' Julianne Moore',
#                 ' Liam Hemsworth',
#                 ' Philip Seymour Hoffman',
#                 ' Sam Claflin',
#                 ' Willow Shields',
#                 ' Woody Harrelson'],
#   'parental_rating': 'PG-13',
#   'release_date': 'November 20, 2015',
#   'runtime': '137 min',
#   'studio': 'Lionsgate',
#   'title': 'The Hunger Games: Mockingjay - Part 2',
#   'user_score': '6.7'},
#  {'critic_score': '62',
#   'director': 'Andy Wachowski and Lana Wachowski',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'main_cast': '',
#   'parental_rating': 'R',
#   'release_date': 'May 15, 2003',
#   'runtime': '138 min',
#   'studio': 'Warner Bros. Pictures',
#   'title': 'The Matrix Reloaded',
#   'user_score': '7.7'},
#  {'critic_score': '45',
#   'director': 'Bill Condon',
#   'genres': ['Drama', 'Thriller', 'Fantasy', 'Romance'],
#   'main_cast': ['Dakota Fanning',
#                 ' Kristen Stewart',
#                 ' Robert Pattinson',
#                 ' Taylor Lautner'],
#   'parental_rating': 'PG-13',
#   'release_date': 'November 18, 2011',
#   'runtime': '117 min',
#   'studio': 'Summit Entertainment',
#   'title': 'The Twilight Saga: Breaking Dawn, Part 1',
#   'user_score': '4.6'},
#  {'critic_score': '41',
#   'director': 'Jay Roach',
#   'genres': ['Comedy', 'Romance'],
#   'main_cast': ['Barbra Streisand',
#                 ' Ben Stiller',
#                 ' Blythe Danner',
#                 ' Dustin Hoffman',
#                 ' Robert De Niro',
#                 ' Teri Polo'],
#   'parental_rating': 'PG-13',
#   'release_date': 'December 22, 2004',
#   'runtime': '115 min',
#   'studio': 'Universal Pictures',
#   'title': 'Meet the Fockers',
#   'user_score': '7.0'},
#  {'critic_score': '73',
#   'director': 'Todd Phillips',
#   'genres': ['Comedy', 'Crime'],
#   'main_cast': ['Bradley Cooper', ' Justin Bartha', ' Zach Galifianakis'],
#   'parental_rating': 'Unrated',
#   'release_date': 'June 5, 2009',
#   'runtime': '100 min',
#   'studio': 'Warner Bros. Pictures',
#   'title': 'The Hangover',
#   'user_score': '7.8'},
#  {'critic_score': '96',
#   'director': 'Alfonso Cuarón',
#   'genres': ['Sci-Fi', 'Drama', 'Mystery', 'Thriller'],
#   'main_cast': ['George Clooney', ' Sandra Bullock'],
#   'parental_rating': 'PG-13',
#   'release_date': 'October 4, 2013',
#   'runtime': '91 min',
#   'studio': 'Warner Bros. Pictures',
#   'title': 'Gravity',
#   'user_score': '7.8'},
#  {'critic_score': '59',
#   'director': 'Christophe Lourdelet and Garth Jennings',
#   'genres': ['Drama', 'Comedy', 'Music', 'Animation', 'Family', 'Musical'],
#   'main_cast': ['Jennifer Hudson',
#                 ' Jennifer Saunders',
#                 ' John C. Reilly',
#                 ' Matthew McConaughey',
#                 ' Reese Witherspoon',
#                 ' Scarlett Johansson',
#                 ' Seth MacFarlane',
#                 ' Taron Egerton',
#                 ' Tori Kelly'],
#   'parental_rating': 'PG',
#   'release_date': 'December 21, 2016',
#   'runtime': '108 min',
#   'studio': 'Universal Pictures',
#   'title': 'Sing',
#   'user_score': '6.2'}]

# %%
# Create DataFrame
top_100_grossing_metacritic_pd = pd.DataFrame(top_100_grossing_metacritic_dicts)[['title','release_date','critic_score','user_score','studio','director','main_cast','genres','parental_rating','runtime']]
top_100_grossing_metacritic_pd.head()
# Out:
#                                   title       release_date critic_score  \
# 0  Star Wars Ep. VII: The Force Awakens  December 18, 2015           81
# 1                                Avatar  December 18, 2009           83
# 2                         Black Panther  February 16, 2018           88
# 3                Avengers: Infinity War     April 27, 2018           68
# 4                               Titanic  December 19, 1997           75
#
#   user_score                                  studio  \
# 0        6.8     Walt Disney Studios Motion Pictures
# 1        7.5  Twentieth Century Fox Film Corporation
# 2        6.6     Walt Disney Studios Motion Pictures
# 3        8.6     Walt Disney Studios Motion Pictures
# 4        8.5                      Paramount Pictures
#
#                       director  \
# 0                  J.J. Abrams
# 1                James Cameron
# 2                 Ryan Coogler
# 3  Anthony Russo and Joe Russo
# 4                James Cameron
#
#                                            main_cast  \
# 0  [Adam Driver,  Carrie Fisher,  Daisy Ridley,  ...
# 1  [Michelle Rodriguez,  Sam Worthington,  Sigour...
# 2  [Andy Serkis,  Angela Bassett,  Chadwick Bosem...
# 3  [Angela Bassett,  Benedict Cumberbatch,  Benic...
# 4                 [Kate Winslet,  Leonardo DiCaprio]
#
#                                  genres parental_rating  runtime
# 0  [Action, Adventure, Sci-Fi, Fantasy]           PG-13  135 min
# 1  [Action, Adventure, Sci-Fi, Fantasy]           PG-13  162 min
# 2    [Action, Adventure, Sci-Fi, Drama]           PG-13  134 min
# 3  [Action, Adventure, Sci-Fi, Fantasy]           PG-13  149 min
# 4                      [Drama, Romance]           PG-13  194 min

# %%
# Merge with Base Table
new_base_df = pd.merge(base_df2, top_100_grossing_metacritic_pd, on='title')
new_base_df.head()
# Out:
#    Rank  Released                                 title DomesticBox Office  \
# 0     1      2015  Star Wars Ep. VII: The Force Awakens          936662225
# 1     2      2009                                Avatar          760507625
# 2     3      2018                         Black Panther          700059566
# 3     4      2018                Avengers: Infinity War          678815482
# 4     5      1997                               Titanic          659363944
#
#   InternationalBox Office WorldwideBox Office       release_date critic_score  \
# 0                 1116648             2053311  December 18, 2015           81
# 1                 2015837             2776345  December 18, 2009           83
# 2               648300000             1348359  February 16, 2018           88
# 3                 1369988             2048803     April 27, 2018           68
# 4                 1548844             2208208  December 19, 1997           75
#
#   user_score                                  studio  \
# 0        6.8     Walt Disney Studios Motion Pictures
# 1        7.5  Twentieth Century Fox Film Corporation
# 2        6.6     Walt Disney Studios Motion Pictures
# 3        8.6     Walt Disney Studios Motion Pictures
# 4        8.5                      Paramount Pictures
#
#                       director  \
# 0                  J.J. Abrams
# 1                James Cameron
# 2                 Ryan Coogler
# 3  Anthony Russo and Joe Russo
# 4                James Cameron
#
#                                            main_cast  \
# 0  [Adam Driver,  Carrie Fisher,  Daisy Ridley,  ...
# 1  [Michelle Rodriguez,  Sam Worthington,  Sigour...
# 2  [Andy Serkis,  Angela Bassett,  Chadwick Bosem...
# 3  [Angela Bassett,  Benedict Cumberbatch,  Benic...
# 4                 [Kate Winslet,  Leonardo DiCaprio]
#
#                                  genres parental_rating  runtime
# 0  [Action, Adventure, Sci-Fi, Fantasy]           PG-13  135 min
# 1  [Action, Adventure, Sci-Fi, Fantasy]           PG-13  162 min
# 2    [Action, Adventure, Sci-Fi, Drama]           PG-13  134 min
# 3  [Action, Adventure, Sci-Fi, Fantasy]           PG-13  149 min
# 4                      [Drama, Romance]           PG-13  194 min
