# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests
import string
from pprint import pprint

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
base_url = 'https://www.rottentomatoes.com/m/'
# add the correct User-Agent
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36'}

# %%
def get_url(base_url, movie_name):
    # remove punctuation from movie name if it has
    title = ''.join(item for item in movie_name if item not in string.punctuation or item == '-')
                
    tag_list = title.lower().split()
    tag = ''
    
    for item in tag_list:
        if(item == 'ep'):
            item = 'episode'
        
        if('-' in item):
            item = item.replace('-', '_')
        
        if(item != tag_list[-1]):
            tag = tag + str(item) + '_'
        else:
            tag = tag + str(item)
    
    url = base_url + tag
    
    return url

# %%
get_url(base_url, 'Harry Potter and the Half-Blood Prince')
# Out:
# Harry Potter and the Half-Blood Prince
# 'https://www.rottentomatoes.com/m/harry_potter_and_the_half_blood_prince'

# %%
movie_data = pd.read_csv('../movie_base.csv')
movie_data.head()
# Out:
#    Unnamed: 0  Rank  Released                                 Movie  \
# 0           0     1      2015  Star Wars Ep. VII: The Force Awakens
# 1           1     2      2009                                Avatar
# 2           2     3      2018                         Black Panther
# 3           3     4      2018                Avengers: Infinity War
# 4           4     5      1997                               Titanic
#
#    DomesticBox Office  InternationalBox Office  WorldwideBox Office
# 0           936662225                  1116648              2053311
# 1           760507625                  2015837              2776345
# 2           700059566                648300000              1348359
# 3           678815482                  1369988              2048803
# 4           659363944                  1548844              2208208

# %%
# get url list waiting to crawl
tomato_movie_data = {
    'url': []
}

for movie in movie_data.Movie:
    tomato_movie_data['url'].append(get_url(base_url, movie))

# %%
# check if url is valide in rotten tomato
def get_html(url):
    try:
        r = requests.get(url, timeout=30)
        r.raise_for_status
        #site encoding
        r.encoding = 'utf-8'
        return r.text
    except:
        print('ERROR')
        pass

# %%
def get_content(url):
    html = get_html(url)
    soup = bs(html, 'lxml')
    data = {}
    try:
        try:
            data['cretic(%)'] = soup.find('span', class_='superPageFontColor').span.text
        except:
            data['cretic(%)'] = 'na'
            
        try:
            data['cretic_rate'] = soup.find('div', id='scoreStats').findChildren()[0].text[25:].strip()
        except:
            data['cretic_rate'] = 'na'
            
        try:
            data['cretic_count'] = soup.find('div', id='scoreStats').findChildren()[2].text[18:].strip()
        except:
            data['cretic_count'] = 'na'
            
        try:
            data['cretic_fresh'] = soup.find('div', id='scoreStats').findChildren()[7].text
        except:
            data['cretic_fresh'] = 'na'
        
        try:
            data['cretic_rot'] = soup.find('div', id='scoreStats').findChildren()[10].text
        except:
            data['cretic_rot'] = 'na'
            
        try:
            data['user(%)'] = soup.find('div', class_='audience-score').find('span', class_='superPageFontColor').text[:2]
        except:
            data['user(%)'] = 'na'
            
        try:
            data['user_rate'] = soup.find('div', class_='audience-info').findChildren()[0].contents[2].strip()
        except:
            data['user_rate'] = 'na'
        
        try:
            data['user_number'] = soup.find('div', class_='audience-info').findChildren()[2].contents[2].strip()
        except:
            data['user_number'] = 'na'

    except:
        print('error')
    
    return data

# %%
movie_crawl_list = []
for url in tomato_movie_data['url']:
    data = get_content(url)
    movie_crawl_list.append(data)

# %%
tomato_data = pd.DataFrame(data=movie_crawl_list,
                           columns=["cretic(%)", "cretic_count", 'cretic_fresh', 'cretic_rate', 'cretic_rot',
                                   'user(%)', 'user_number', 'user_rate'])
tomato_data['name'] = movie_data['Movie']
tomato_data['url'] = tomato_movie_data['url']

# %%
tomato_list_clean = tomato_data.loc[tomato_data['cretic(%)'] != 'na']
tomato_list_clean.to_csv('tomato.csv')

# %%
tomato_data.loc[tomato_data['cretic(%)'] == 'na'][['name', 'url']]
# Out:
#                                                 name  \
# 2                                      Black Panther
# 6                                       The Avengers
# 7                  Star Wars Ep. VIII: The Last Jedi
# 11                              Beauty and the Beast
# 14                      Star Wars Ep. IV: A New Hope
# 20      Pirates of the Caribbean: Dead Manâs Chest
# 38                              Beauty and the Beast
# 40                         The Passion of the Christ
# 43                                   The Jungle Book
# 45                                        Inside Out
# 54                            Spider-Man: Homecoming
# 55                               Alice in Wonderland
# 59                                                It
# 60                                     Suicide Squad
# 63                                      Transformers
# 65           Harry Potter and the Sorcererâs Stone
# 71        Pirates of the Caribbean: At Worldâs End
# 73                                  Independence Day
# 74  Pirates of the Caribbean: The Curse of the Blac…
# 77            Harry Potter and the Half-Blood Prince
# 81                                   The Sixth Sense
# 87  The Chronicles of Narnia: The Lion, the Witch a…
# 88                                      Man of Steel
# 89          Star Wars Ep. V: The Empire Strikes Back
# 98                                           Gravity
#
#                                                   url
# 2      https://www.rottentomatoes.com/m/black_panther
# 6       https://www.rottentomatoes.com/m/the_avengers
# 7   https://www.rottentomatoes.com/m/star_wars_epi...
# 11  https://www.rottentomatoes.com/m/beauty_and_th...
# 14  https://www.rottentomatoes.com/m/star_wars_epi...
# 20  https://www.rottentomatoes.com/m/pirates_of_th...
# 38  https://www.rottentomatoes.com/m/beauty_and_th...
# 40  https://www.rottentomatoes.com/m/the_passion_o...
# 43   https://www.rottentomatoes.com/m/the_jungle_book
# 45        https://www.rottentomatoes.com/m/inside_out
# 54  https://www.rottentomatoes.com/m/spiderman_hom...
# 55  https://www.rottentomatoes.com/m/alice_in_wond...
# 59                https://www.rottentomatoes.com/m/it
# 60     https://www.rottentomatoes.com/m/suicide_squad
# 63      https://www.rottentomatoes.com/m/transformers
# 65  https://www.rottentomatoes.com/m/harry_potter_...
# 71  https://www.rottentomatoes.com/m/pirates_of_th...
# 73  https://www.rottentomatoes.com/m/independence_day
# 74  https://www.rottentomatoes.com/m/pirates_of_th...
# 77  https://www.rottentomatoes.com/m/harry_potter_...
# 81   https://www.rottentomatoes.com/m/the_sixth_sense
# 87  https://www.rottentomatoes.com/m/the_chronicle...
# 88      https://www.rottentomatoes.com/m/man_of_steel
# 89  https://www.rottentomatoes.com/m/star_wars_epi...
# 98           https://www.rottentomatoes.com/m/gravity

# %%
tomato_data.loc[tomato_data['name'] == 'Harry Potter and the Half-Blood Prince'].url
# Out:
# 77    https://www.rottentomatoes.com/m/harry_potter_...
# Name: url, dtype: object

# %%
tomato_plot = pd.read_csv('tomato.csv').set_index('name')
tomato_fresh = tomato_plot[['cretic(%)', 'user(%)']].plot(kind='barh', figsize=(7, 21))
