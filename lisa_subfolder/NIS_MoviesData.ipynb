# %%
# import dependencies
import pandas as pd

# %%
# load file
file = "NIS/MovieData.csv"

# %%
# read file and store into pandas dataframe
movie_data = pd.read_csv(file)

# %%
movie_data.head()
# Out:
#                movie_name  production_year  movie_odid  production_budget  \
# 0        Peaceful Warrior             2006    52640100           10000000
# 1        End of the Spear             2006    34620100           10000000
# 2                  Krrish             2006    58540100           10000000
# 3  Madea's Family Reunion             2006     8220100           10000000
# 4   Employee of the Month             2006    19540100           10000000
#
#    domestic_box_office  international_box_office     rating  \
# 0              2893666                    366513      PG-13
# 1             11748661                    175380      PG-13
# 2              1430721                  31000000  Not Rated
# 3             63257940                     62581      PG-13
# 4             28444855                   9920000      PG-13
#
#           creative_type                             source production_method  \
# 0         Dramatization  Based on Fiction Book/Short Story       Live Action
# ...

# %%
# this is an old dataset which we have chosen not to use
